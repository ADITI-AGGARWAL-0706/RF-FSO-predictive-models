# %%
import pandas as pd

# Load the dataset 
file_path = r"C:\Users\punee\Downloads\Aditi coding\RFLFSODataFull.csv"
data = pd.read_csv(file_path)

# Creating separate data subsets for each weather condition
clear_data = data[data['SYNOPCode'] == 0]      
dust_storm_data = data[data['SYNOPCode'] == 3] 
fog_data = data[data['SYNOPCode'] == 4]         
drizzle_data = data[data['SYNOPCode'] == 5]    
rain_data = data[data['SYNOPCode'] == 6]        
snow_data = data[data['SYNOPCode'] == 7]        
showers_data = data[data['SYNOPCode'] == 8]    

# Verify the size of each subset 
print("Number of entries in each subset:")
print("Clear:", len(clear_data))
print("Dust Storm:", len(dust_storm_data))
print("Fog:", len(fog_data))
print("Drizzle:", len(drizzle_data))
print("Rain:", len(rain_data))
print("Snow:", len(snow_data))
print("Showers:", len(showers_data))
# Out:
# Number of entries in each subset:
# Clear: 56964
# Dust Storm: 191
# Fog: 466
# Drizzle: 6605
# Rain: 25018
# Snow: 419
# Showers: 1716

# %%
# Filter the data to get only the "Drizzle" weather condition 
drizzle_data = data[data['SYNOPCode'] == 5]
# Filter rows with RFL data (where 'RFL_Att' has values)
drizzle_rfl_data = drizzle_data.dropna(subset=['RFL_Att'])

# Filter rows with FSO data (where 'FSO_Att' has values)
drizzle_fso_data = drizzle_data.dropna(subset=['FSO_Att'])

# Verify the sizes of each subset
print("Number of entries in Drizzle (RFL):", len(drizzle_rfl_data))
print("Number of entries in Drizzle (FSO):", len(drizzle_fso_data))
# Out:
# Number of entries in Drizzle (RFL): 6605
# Number of entries in Drizzle (FSO): 6605

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Assuming you have already run Step 1 and created drizzle_rfl_data and drizzle_fso_data

def evaluate_models(data, target_column):
    # Drop columns that are not predictors (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Set the target column, either 'RFL_Att' or 'FSO_Att'
    
    # Prepare to store RMSE and R^2 scores for each feature removed
    rmse_scores = []
    r2_scores = []
    removed_features = []

    # Loop through each column, removing it and training a model
    for feature in predictors.columns:
        # Drop the feature from the predictors
        predictors_subset = predictors.drop(columns=[feature])
        
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(predictors_subset, target, test_size=0.3, random_state=42)
        
        # Train a Random Forest model
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)
        
        # Predictions on test data
        y_pred = model.predict(X_test)
        
        # Calculate RMSE and R^2
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store the results
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        removed_features.append(feature)
        
        # Print results for each model
        print(f"Feature removed: {feature}")
        print(f"RMSE: {rmse:.4f}, R^2: {r2:.4f}")
    
    # Store the results in a DataFrame for easier handling
    results_df = pd.DataFrame({
        'Removed Feature': removed_features,
        'RMSE': rmse_scores,
        'R^2': r2_scores
    })
    
    return results_df

# Run evaluation on Drizzle RFL data
print("Evaluating models for Drizzle Weather - RFL subset")
drizzle_rfl_results = evaluate_models(drizzle_rfl_data, target_column='RFL_Att')

# Run evaluation on Drizzle FSO data
print("\nEvaluating models for Drizzle Weather - FSO subset")
drizzle_fso_results = evaluate_models(drizzle_fso_data, target_column='FSO_Att')
# Out:
# Evaluating models for Drizzle Weather - RFL subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.7406, R^2: 0.9367
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.7048, R^2: 0.9427
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.6968, R^2: 0.9439
# Feature removed: Distance
# RMSE: 0.7916, R^2: 0.9277
# Feature removed: Frequency
# RMSE: 0.8020, R^2: 0.9258
# Feature removed: Particulate
# RMSE: 0.7022, R^2: 0.9431
# Feature removed: ParticulateMax
# RMSE: 0.7007, R^2: 0.9433
# Feature removed: ParticulateMin
# RMSE: 0.7015, R^2: 0.9432
# Feature removed: RainIntensity
# RMSE: 0.7044, R^2: 0.9427
# Feature removed: RainIntensityMax
# RMSE: 0.7052, R^2: 0.9426
# Feature removed: RainIntensityMin
# RMSE: 0.7045, R^2: 0.9427
# Feature removed: RelativeHumidity
# RMSE: 0.7003, R^2: 0.9434
# Feature removed: Temperature
# RMSE: 0.7075, R^2: 0.9422
# Feature removed: TemperatureDifference
# RMSE: 0.7233, R^2: 0.9396
# Feature removed: TemperatureMax
# RMSE: 0.6997, R^2: 0.9435
# Feature removed: TemperatureMin
# RMSE: 0.6956, R^2: 0.9442
# Feature removed: Time
# RMSE: 0.7207, R^2: 0.9401
# Feature removed: Visibility
# RMSE: 0.7044, R^2: 0.9427
# Feature removed: VisibilityMax
# RMSE: 0.7030, R^2: 0.9430
# Feature removed: VisibilityMin
# RMSE: 0.7069, R^2: 0.9423
# Feature removed: WindDirection
# RMSE: 0.6964, R^2: 0.9440
# Feature removed: WindSpeed
# RMSE: 0.7049, R^2: 0.9426
# Feature removed: WindSpeedMax
# RMSE: 0.7041, R^2: 0.9428
# Feature removed: WindSpeedMin
# RMSE: 0.7026, R^2: 0.9430
#
# Evaluating models for Drizzle Weather - FSO subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.9953, R^2: 0.9244
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.9921, R^2: 0.9249
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.9989, R^2: 0.9239
# Feature removed: Distance
# RMSE: 1.1215, R^2: 0.9040
# Feature removed: Frequency
# RMSE: 0.9983, R^2: 0.9239
# Feature removed: Particulate
# RMSE: 0.9957, R^2: 0.9243
# Feature removed: ParticulateMax
# RMSE: 0.9969, R^2: 0.9242
# Feature removed: ParticulateMin
# RMSE: 0.9969, R^2: 0.9242
# Feature removed: RainIntensity
# RMSE: 0.9996, R^2: 0.9238
# Feature removed: RainIntensityMax
# RMSE: 1.0023, R^2: 0.9233
# Feature removed: RainIntensityMin
# RMSE: 0.9981, R^2: 0.9240
# Feature removed: RelativeHumidity
# RMSE: 1.0229, R^2: 0.9201
# Feature removed: Temperature
# RMSE: 1.0067, R^2: 0.9227
# Feature removed: TemperatureDifference
# RMSE: 1.0298, R^2: 0.9191
# Feature removed: TemperatureMax
# RMSE: 0.9939, R^2: 0.9246
# Feature removed: TemperatureMin
# RMSE: 0.9882, R^2: 0.9255
# Feature removed: Time
# RMSE: 1.0397, R^2: 0.9175
# Feature removed: Visibility
# RMSE: 1.0064, R^2: 0.9227
# Feature removed: VisibilityMax
# RMSE: 0.9812, R^2: 0.9265
# Feature removed: VisibilityMin
# RMSE: 1.0021, R^2: 0.9234
# Feature removed: WindDirection
# RMSE: 0.9780, R^2: 0.9270
# Feature removed: WindSpeed
# RMSE: 0.9967, R^2: 0.9242
# Feature removed: WindSpeedMax
# RMSE: 1.0019, R^2: 0.9234
# Feature removed: WindSpeedMin
# RMSE: 0.9963, R^2: 0.9242

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def final_random_forest_model(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Target is either 'RFL_Att' or 'FSO_Att'

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

    # Train a Random Forest model using all features
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X_train, y_train)

    # Predictions on test data
    y_pred = model.predict(X_test)

    # Calculate RMSE and R^2 for test data
    rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_test = r2_score(y_test, y_pred)

    # Calculate OOB RMSE and R^2 (training data) for comparison
    rmse_oob = np.sqrt(mean_squared_error(y_train, model.oob_prediction_))
    r2_oob = r2_score(y_train, model.oob_prediction_)

    # Print and return results
    print(f"Final Random Forest Model for {target_column}")
    print(f"Test RMSE: {rmse_test:.4f}, Test R^2: {r2_test:.4f}")
    print(f"OOB RMSE (Training): {rmse_oob:.4f}, OOB R^2 (Training): {r2_oob:.4f}")

    return {
        'Test RMSE': rmse_test,
        'Test R^2': r2_test,
        'OOB RMSE (Training)': rmse_oob,
        'OOB R^2 (Training)': r2_oob
    }

# Run final Random Forest model on Drizzle RFL data
print("Evaluating final model for Drizzle Weather - RFL subset")
drizzle_rfl_final_results = final_random_forest_model(drizzle_rfl_data, target_column='RFL_Att')

# Run final Random Forest model on Drizzle FSO data
print("\nEvaluating final model for Drizzle Weather - FSO subset")
drizzle_fso_final_results = final_random_forest_model(drizzle_fso_data, target_column='FSO_Att')
# Out:
# Evaluating final model for Drizzle Weather - RFL subset
# Final Random Forest Model for RFL_Att
# Test RMSE: 0.7053, Test R^2: 0.9426
# OOB RMSE (Training): 0.5852, OOB R^2 (Training): 0.9579
#
# Evaluating final model for Drizzle Weather - FSO subset
# Final Random Forest Model for FSO_Att
# Test RMSE: 1.0044, Test R^2: 0.9230
# OOB RMSE (Training): 0.9591, OOB R^2 (Training): 0.9274

# %%
import pandas as pd

def calculate_feature_importance_differences(results_df, full_model_results):
    # Calculate the absolute differences in RMSE and R^2 between training (OOB) and test datasets
    results_df['RMSE Difference'] = abs(full_model_results['OOB RMSE (Training)'] - results_df['RMSE'])
    results_df['R^2 Difference'] = abs(full_model_results['OOB R^2 (Training)'] - results_df['R^2'])
    
    # Rank features by importance based on the sum of RMSE and R^2 differences
    results_df['Importance Score'] = results_df['RMSE Difference'] + results_df['R^2 Difference']
    
    # Sort by importance score in descending order
    results_df = results_df.sort_values(by='Importance Score', ascending=False).reset_index(drop=True)
    
    return results_df[['Removed Feature', 'RMSE Difference', 'R^2 Difference', 'Importance Score']]


print("Calculating feature importance for Drizzle Weather - RFL subset")
drizzle_rfl_importance = calculate_feature_importance_differences(drizzle_rfl_results, drizzle_rfl_final_results)
print(drizzle_rfl_importance)

print("\nCalculating feature importance for Drizzle Weather - FSO subset")
drizzle_fso_importance = calculate_feature_importance_differences(drizzle_fso_results, drizzle_fso_final_results)
print(drizzle_fso_importance)
# Out:
# Calculating feature importance for Drizzle Weather - RFL subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0               Frequency         0.216741        0.032178          0.248918
# 1                Distance         0.206341        0.030265          0.236606
# 2        AbsoluteHumidity         0.155361        0.021249          0.176610
# 3   TemperatureDifference         0.138034        0.018321          0.156355
# 4                    Time         0.135442        0.017889          0.153331
# 5             Temperature         0.122300        0.015723          0.138023
# 6           VisibilityMin         0.121657        0.015618          0.137275
# 7        RainIntensityMax         0.119953        0.015340          0.135293
# 8               WindSpeed         0.119682        0.015296          0.134977
# 9     AbsoluteHumidityMax         0.119590        0.015281          0.134871
# 10       RainIntensityMin         0.119270        0.015229          0.134499
# 11          RainIntensity         0.119188        0.015216          0.134404
# 12             Visibility         0.119156        0.015210          0.134366
# 13           WindSpeedMax         0.118924        0.015173          0.134097
# 14          VisibilityMax         0.117794        0.014989          0.132783
# 15           WindSpeedMin         0.117424        0.014929          0.132352
# 16            Particulate         0.116937        0.014850          0.131787
# 17         ParticulateMin         0.116239        0.014737          0.130975
# 18         ParticulateMax         0.115487        0.014615          0.130102
# 19       RelativeHumidity         0.115112        0.014555          0.129667
# 20         TemperatureMax         0.114462        0.014450          0.128912
# 21    AbsoluteHumidityMin         0.111625        0.013992          0.125617
# 22          WindDirection         0.111214        0.013926          0.125140
# 23         TemperatureMin         0.110353        0.013788          0.124141
#
# Calculating feature importance for Drizzle Weather - FSO subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0                Distance         0.162381        0.023395          0.185776
# 1                    Time         0.080641        0.009914          0.090556
# 2   TemperatureDifference         0.070675        0.008341          0.079016
# 3        RelativeHumidity         0.063846        0.007271          0.071117
# 4             Temperature         0.047615        0.004757          0.052371
# 5              Visibility         0.047289        0.004707          0.051996
# 6        RainIntensityMax         0.043152        0.004073          0.047225
# 7           VisibilityMin         0.042965        0.004044          0.047009
# 8            WindSpeedMax         0.042792        0.004018          0.046810
# 9           RainIntensity         0.040456        0.003661          0.044117
# 10    AbsoluteHumidityMin         0.039799        0.003561          0.043359
# 11              Frequency         0.039227        0.003474          0.042700
# 12       RainIntensityMin         0.038961        0.003433          0.042394
# 13         ParticulateMin         0.037772        0.003252          0.041025
# 14         ParticulateMax         0.037772        0.003252          0.041025
# 15              WindSpeed         0.037574        0.003222          0.040795
# 16           WindSpeedMin         0.037240        0.003171          0.040412
# 17            Particulate         0.036592        0.003073          0.039665
# 18       AbsoluteHumidity         0.036165        0.003008          0.039173
# 19         TemperatureMax         0.034759        0.002794          0.037553
# 20    AbsoluteHumidityMax         0.033030        0.002532          0.035563
# 21         TemperatureMin         0.029147        0.001946          0.031093
# 22          VisibilityMax         0.022109        0.000888          0.022996
# 23          WindDirection         0.018927        0.000412          0.019339

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

def iterative_feature_removal(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]
    
    # Prepare a DataFrame to store the results
    results = pd.DataFrame(columns=['Remaining Features', 'OOB RMSE', 'OOB R^2'])

    # Initialize the list of features to be removed iteratively
    remaining_features = list(predictors.columns)

    while remaining_features:
        # Train the Random Forest model with current set of features
        model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
        model.fit(predictors[remaining_features], target)

        # Calculate OOB RMSE and R^2
        oob_predictions = model.oob_prediction_
        oob_rmse = np.sqrt(mean_squared_error(target, oob_predictions))
        oob_r2 = r2_score(target, oob_predictions)

        # Record the current state
        result_row = pd.DataFrame({
            'Remaining Features': [remaining_features.copy()],
            'OOB RMSE': [oob_rmse],
            'OOB R^2': [oob_r2]
        })
        results = pd.concat([results, result_row], ignore_index=True)

        # Rank features by importance and remove the least important feature
        importances = model.feature_importances_
        least_important_feature = remaining_features[np.argmin(importances)]
        remaining_features.remove(least_important_feature)
        
        # Print the step results
        print(f"Features: {remaining_features}")
        print(f"OOB RMSE: {oob_rmse:.4f}, OOB R^2: {oob_r2:.4f}")
        print(f"Removed Feature: {least_important_feature}\n")
    
    return results

# Run iterative feature removal on Drizzle RFL subset
print("Iterative feature removal for Drizzle Weather - RFL subset")
drizzle_rfl_removal_results = iterative_feature_removal(drizzle_rfl_data, target_column='RFL_Att')

# Run iterative feature removal on Drizzle FSO subset
print("\nIterative feature removal for Drizzle Weather - FSO subset")
drizzle_fso_removal_results = iterative_feature_removal(drizzle_fso_data, target_column='FSO_Att')
# Out:
# Iterative feature removal for Drizzle Weather - RFL subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_14768\2999151281.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5496, OOB R^2: 0.9636
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.5489, OOB R^2: 0.9637
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.5512, OOB R^2: 0.9634
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.5451, OOB R^2: 0.9642
# Removed Feature: TemperatureMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.5429, OOB R^2: 0.9645
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.5398, OOB R^2: 0.9649
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.5375, OOB R^2: 0.9652
# Removed Feature: VisibilityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.5372, OOB R^2: 0.9652
# Removed Feature: TemperatureMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.5335, OOB R^2: 0.9657
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.5331, OOB R^2: 0.9658
# Removed Feature: Time
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Visibility']
# OOB RMSE: 0.5551, OOB R^2: 0.9629
# Removed Feature: VisibilityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureDifference', 'Visibility']
# OOB RMSE: 0.5550, OOB R^2: 0.9629
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureDifference', 'Visibility']
# OOB RMSE: 0.5673, OOB R^2: 0.9612
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Visibility']
# OOB RMSE: 0.5726, OOB R^2: 0.9605
# Removed Feature: TemperatureDifference
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Visibility']
# OOB RMSE: 0.6148, OOB R^2: 0.9545
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RainIntensity', 'RainIntensityMax', 'RelativeHumidity', 'Visibility']
# OOB RMSE: 0.7111, OOB R^2: 0.9391
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RainIntensity', 'RainIntensityMax', 'RelativeHumidity']
# OOB RMSE: 0.7099, OOB R^2: 0.9393
# Removed Feature: Visibility
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RainIntensity', 'RainIntensityMax']
# OOB RMSE: 0.7915, OOB R^2: 0.9245
# Removed Feature: RelativeHumidity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax']
# OOB RMSE: 0.8722, OOB R^2: 0.9083
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'RainIntensityMax']
# OOB RMSE: 1.0379, OOB R^2: 0.8702
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin']
# OOB RMSE: 1.0406, OOB R^2: 0.8695
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin']
# OOB RMSE: 1.4989, OOB R^2: 0.7293
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity']
# OOB RMSE: 1.5290, OOB R^2: 0.7183
# Removed Feature: AbsoluteHumidityMin
#
# Features: []
# OOB RMSE: 1.6832, OOB R^2: 0.6586
# Removed Feature: AbsoluteHumidity
#
#
# Iterative feature removal for Drizzle Weather - FSO subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_14768\2999151281.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8351, OOB R^2: 0.9455
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8351, OOB R^2: 0.9455
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8228, OOB R^2: 0.9471
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8249, OOB R^2: 0.9469
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8141, OOB R^2: 0.9482
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8075, OOB R^2: 0.9491
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8036, OOB R^2: 0.9496
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8020, OOB R^2: 0.9498
# Removed Feature: WindSpeedMax
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8186, OOB R^2: 0.9477
# Removed Feature: AbsoluteHumidity
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8237, OOB R^2: 0.9470
# Removed Feature: RainIntensity
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8052, OOB R^2: 0.9494
# Removed Feature: TemperatureDifference
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8489, OOB R^2: 0.9437
# Removed Feature: WindSpeed
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8677, OOB R^2: 0.9412
# Removed Feature: RelativeHumidity
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8998, OOB R^2: 0.9368
# Removed Feature: TemperatureMin
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMax', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8812, OOB R^2: 0.9394
# Removed Feature: Time
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMax', 'Visibility', 'VisibilityMax']
# OOB RMSE: 1.0180, OOB R^2: 0.9191
# Removed Feature: VisibilityMin
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'Temperature', 'TemperatureMax', 'Visibility', 'VisibilityMax']
# OOB RMSE: 1.0070, OOB R^2: 0.9208
# Removed Feature: ParticulateMin
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'Temperature', 'Visibility', 'VisibilityMax']
# OOB RMSE: 0.9970, OOB R^2: 0.9224
# Removed Feature: TemperatureMax
#
# Features: ['Distance', 'ParticulateMax', 'Temperature', 'Visibility', 'VisibilityMax']
# OOB RMSE: 0.9833, OOB R^2: 0.9245
# Removed Feature: Particulate
#
# Features: ['Distance', 'ParticulateMax', 'Temperature', 'Visibility']
# OOB RMSE: 0.9758, OOB R^2: 0.9256
# Removed Feature: VisibilityMax
#
# Features: ['Distance', 'ParticulateMax', 'Visibility']
# OOB RMSE: 0.9557, OOB R^2: 0.9287
# Removed Feature: Temperature
#
# Features: ['Distance', 'ParticulateMax']
# OOB RMSE: 1.6407, OOB R^2: 0.7898
# Removed Feature: Visibility
#
# Features: ['Distance']
# OOB RMSE: 2.3007, OOB R^2: 0.5866
# Removed Feature: ParticulateMax
#
# Features: []
# OOB RMSE: 3.4503, OOB R^2: 0.0702
# Removed Feature: Distance

# %%
print(drizzle_rfl_removal_results.columns)
# Out:
# Index(['Remaining Features', 'OOB RMSE', 'OOB R^2'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def add_removed_feature_column(results_df):
    # Extract all features in the initial (first row) 'Remaining Features' column
    all_features = set(results_df['Remaining Features'].iloc[0])
    
    # Initialize a list to store removed features
    removed_features = []
    
    # Set to track already removed features
    remaining_features = all_features.copy()

    # Compute removed features at each step
    for i in range(len(results_df)):
        current_features = set(results_df['Remaining Features'].iloc[i])
        removed = list(remaining_features - current_features)
        
        # Add the removed feature to the list, and remove it from the remaining features set
        if removed:
            removed_feature = removed[0]
            removed_features.append(removed_feature)
            remaining_features.remove(removed_feature)
        else:
            removed_features.append(None)  # No feature removed (last step)

    # Add the new column to the DataFrame
    results_df['Removed Feature'] = removed_features
    return results_df

# Update results DataFrames to include 'Removed Feature'
drizzle_rfl_removal_results = add_removed_feature_column(drizzle_rfl_removal_results)
drizzle_fso_removal_results = add_removed_feature_column(drizzle_fso_removal_results)

def plot_rmse_r2(results_df, title):
    # Verify columns exist
    expected_columns = ['OOB RMSE', 'OOB R^2', 'Removed Feature']
    for col in expected_columns:
        if col not in results_df.columns:
            raise KeyError(f"Expected column '{col}' not found in DataFrame.")

    # Extract RMSE, R^2 values, and removed features
    rmse_values = results_df['OOB RMSE']
    r2_values = results_df['OOB R^2']
    features_removed = range(len(results_df))
    removed_feature_names = results_df['Removed Feature']

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    ax1.plot(features_removed, rmse_values, color="blue", marker="o", label="RMSE")
    ax1.set_xlabel("Number of Features Removed")
    ax1.set_ylabel("RMSE (dB)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(features_removed, r2_values, color="orange", marker="o", label="R^2")
    ax2.set_ylabel("R^2", color="orange")
    ax2.tick_params(axis="y", labelcolor="orange")

    # Place the removed feature names horizontally under the x-axis
    ax1.set_xticks(features_removed)
    ax1.set_xticklabels(removed_feature_names, rotation=90, ha='center', fontsize=8, color="black")

    separation_point = len(results_df) - 10
    ax1.axvline(x=separation_point, color="green", linestyle="--", label="Important Feature Separation")

    plt.title(title)
    fig.tight_layout()
    fig.legend(loc="upper right")
    plt.show()

# Plot updated DataFrames with removed feature names under the x-axis in order of removal
plot_rmse_r2(drizzle_rfl_removal_results, "Drizzle Weather - RFL")
plot_rmse_r2(drizzle_fso_removal_results, "Drizzle Weather - FSO")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Identify features to the right of the green line
def get_important_features(results_df, separation_point):
    # Get the features from the green line to the end of the list
    important_features = results_df['Removed Feature'][separation_point:].dropna().tolist()
    return important_features

#  Train Random Forest on selected features
def train_random_forest_on_important_features(data, target_column, important_features):
    # Subset the data to include only the important features
    X = data[important_features]
    y = data[target_column]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X, y)

    # Calculate RMSE and R^2 on OOB (Out-of-Bag) predictions
    oob_predictions = model.oob_prediction_
    rmse = np.sqrt(mean_squared_error(y, oob_predictions))
    r2 = r2_score(y, oob_predictions)
    
    return rmse, r2, model

# Define the separation point (assuming last 10 features are considered important)
separation_point = len(drizzle_rfl_removal_results) - 10

# Get important features based on the green line separation for both RFL and FSO
important_features_rfl = get_important_features(drizzle_rfl_removal_results, separation_point)
important_features_fso = get_important_features(drizzle_fso_removal_results, separation_point)


#  Train and evaluate the model for RFL
rmse_rfl, r2_rfl, model_rfl = train_random_forest_on_important_features(data, 'RFL_Att', important_features_rfl)
print(f"RFL Model - RMSE: {rmse_rfl:.4f}, R^2: {r2_rfl:.4f}")

#  Train and evaluate the model for FSO
rmse_fso, r2_fso, model_fso = train_random_forest_on_important_features(data, 'FSO_Att', important_features_fso)
print(f"FSO Model - RMSE: {rmse_fso:.4f}, R^2: {r2_fso:.4f}")
# Out:
# RFL Model - RMSE: 0.5854, R^2: 0.9710
# FSO Model - RMSE: 1.6094, R^2: 0.8300
