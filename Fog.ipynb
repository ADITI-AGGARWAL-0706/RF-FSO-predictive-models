# %%
import pandas as pd

# Load the dataset 
file_path = r"C:\Users\punee\Downloads\Aditi coding\RFLFSODataFull.csv"
data = pd.read_csv(file_path)

# Creating separate data subsets for each weather condition
clear_data = data[data['SYNOPCode'] == 0]      
dust_storm_data = data[data['SYNOPCode'] == 3] 
fog_data = data[data['SYNOPCode'] == 4]         
drizzle_data = data[data['SYNOPCode'] == 5]    
rain_data = data[data['SYNOPCode'] == 6]        
snow_data = data[data['SYNOPCode'] == 7]        
showers_data = data[data['SYNOPCode'] == 8]    

# Verify the size of each subset 
print("Number of entries in each subset:")
print("Clear:", len(clear_data))
print("Dust Storm:", len(dust_storm_data))
print("Fog:", len(fog_data))
print("Drizzle:", len(drizzle_data))
print("Rain:", len(rain_data))
print("Snow:", len(snow_data))
print("Showers:", len(showers_data))
# Out:
# Number of entries in each subset:
# Clear: 56964
# Dust Storm: 191
# Fog: 466
# Drizzle: 6605
# Rain: 25018
# Snow: 419
# Showers: 1716

# %%
# Filter the data to get only the "Fog" weather condition 
fog_data = data[data['SYNOPCode'] == 4	]

# Assuming "RFL" and "FSO" refer to the presence of specific values in 'RFL_Att' and 'FSO_Att' columns

# Filter rows with RFL data (where 'RFL_Att' has values)
fog_rfl_data = fog_data.dropna(subset=['RFL_Att'])

# Filter rows with FSO data (where 'FSO_Att' has values)
fog_fso_data = fog_data.dropna(subset=['FSO_Att'])

# Verify the sizes of each subset
print("Number of entries in Fog (RFL):", len(fog_rfl_data))
print("Number of entries in Fog (FSO):", len(fog_fso_data))
# Out:
# Number of entries in Fog (RFL): 466
# Number of entries in Fog (FSO): 466

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np


def evaluate_models(data, target_column):
    # Drop columns that are not predictors (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Set the target column, either 'RFL_Att' or 'FSO_Att'
    
    # Prepare to store RMSE and R^2 scores for each feature removed
    rmse_scores = []
    r2_scores = []
    removed_features = []

    # Loop through each column, removing it and training a model
    for feature in predictors.columns:
        # Drop the feature from the predictors
        predictors_subset = predictors.drop(columns=[feature])
        
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(predictors_subset, target, test_size=0.3, random_state=42)
        
        # Train a Random Forest model
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)
        
        # Predictions on test data
        y_pred = model.predict(X_test)
        
        # Calculate RMSE and R^2
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store the results
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        removed_features.append(feature)
        
        # Print results for each model
        print(f"Feature removed: {feature}")
        print(f"RMSE: {rmse:.4f}, R^2: {r2:.4f}")
    
    # Store the results in a DataFrame for easier handling
    results_df = pd.DataFrame({
        'Removed Feature': removed_features,
        'RMSE': rmse_scores,
        'R^2': r2_scores
    })
    
    return results_df

# Run evaluation on Fog RFL data
print("Evaluating models for Fog Weather - RFL subset")
fog_rfl_results = evaluate_models(fog_rfl_data, target_column='RFL_Att')

# Run evaluation on Fog FSO data
print("\nEvaluating models for Fog Weather - FSO subset")
fog_fso_results = evaluate_models(fog_fso_data, target_column='FSO_Att')
# Out:
# Evaluating models for Fog Weather - RFL subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.4950, R^2: 0.9226
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.4911, R^2: 0.9238
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.5104, R^2: 0.9177
# Feature removed: Distance
# RMSE: 0.4840, R^2: 0.9260
# Feature removed: Frequency
# RMSE: 0.5124, R^2: 0.9171
# Feature removed: Particulate
# RMSE: 0.4884, R^2: 0.9247
# Feature removed: ParticulateMax
# RMSE: 0.4890, R^2: 0.9245
# Feature removed: ParticulateMin
# RMSE: 0.4910, R^2: 0.9239
# Feature removed: RainIntensity
# RMSE: 0.4961, R^2: 0.9223
# Feature removed: RainIntensityMax
# RMSE: 0.4948, R^2: 0.9227
# Feature removed: RainIntensityMin
# RMSE: 0.4958, R^2: 0.9223
# Feature removed: RelativeHumidity
# RMSE: 0.4985, R^2: 0.9215
# Feature removed: Temperature
# RMSE: 0.4973, R^2: 0.9219
# Feature removed: TemperatureDifference
# RMSE: 0.5036, R^2: 0.9199
# Feature removed: TemperatureMax
# RMSE: 0.4997, R^2: 0.9211
# Feature removed: TemperatureMin
# RMSE: 0.5035, R^2: 0.9199
# Feature removed: Time
# RMSE: 0.4924, R^2: 0.9234
# Feature removed: Visibility
# RMSE: 0.4950, R^2: 0.9226
# Feature removed: VisibilityMax
# RMSE: 0.4962, R^2: 0.9222
# Feature removed: VisibilityMin
# RMSE: 0.4970, R^2: 0.9220
# Feature removed: WindDirection
# RMSE: 0.4997, R^2: 0.9211
# Feature removed: WindSpeed
# RMSE: 0.4941, R^2: 0.9229
# Feature removed: WindSpeedMax
# RMSE: 0.4986, R^2: 0.9215
# Feature removed: WindSpeedMin
# RMSE: 0.4989, R^2: 0.9214
#
# Evaluating models for Fog Weather - FSO subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.6144, R^2: 0.9744
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.6237, R^2: 0.9736
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.6064, R^2: 0.9751
# Feature removed: Distance
# RMSE: 0.7463, R^2: 0.9622
# Feature removed: Frequency
# RMSE: 0.6241, R^2: 0.9736
# Feature removed: Particulate
# RMSE: 0.6391, R^2: 0.9723
# Feature removed: ParticulateMax
# RMSE: 0.5945, R^2: 0.9760
# Feature removed: ParticulateMin
# RMSE: 0.6174, R^2: 0.9741
# Feature removed: RainIntensity
# RMSE: 0.6237, R^2: 0.9736
# Feature removed: RainIntensityMax
# RMSE: 0.6257, R^2: 0.9734
# Feature removed: RainIntensityMin
# RMSE: 0.6242, R^2: 0.9736
# Feature removed: RelativeHumidity
# RMSE: 0.6115, R^2: 0.9746
# Feature removed: Temperature
# RMSE: 0.6093, R^2: 0.9748
# Feature removed: TemperatureDifference
# RMSE: 0.6510, R^2: 0.9713
# Feature removed: TemperatureMax
# RMSE: 0.6141, R^2: 0.9744
# Feature removed: TemperatureMin
# RMSE: 0.6204, R^2: 0.9739
# Feature removed: Time
# RMSE: 0.7463, R^2: 0.9622
# Feature removed: Visibility
# RMSE: 0.6277, R^2: 0.9733
# Feature removed: VisibilityMax
# RMSE: 0.6217, R^2: 0.9738
# Feature removed: VisibilityMin
# RMSE: 0.6174, R^2: 0.9741
# Feature removed: WindDirection
# RMSE: 0.6077, R^2: 0.9750
# Feature removed: WindSpeed
# RMSE: 0.6086, R^2: 0.9749
# Feature removed: WindSpeedMax
# RMSE: 0.6093, R^2: 0.9748
# Feature removed: WindSpeedMin
# RMSE: 0.6141, R^2: 0.9744

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def final_random_forest_model(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Target is either 'RFL_Att' or 'FSO_Att'

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

    # Train a Random Forest model using all features
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X_train, y_train)

    # Predictions on test data
    y_pred = model.predict(X_test)

    # Calculate RMSE and R^2 for test data
    rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_test = r2_score(y_test, y_pred)

    # Calculate OOB RMSE and R^2 (training data) for comparison
    rmse_oob = np.sqrt(mean_squared_error(y_train, model.oob_prediction_))
    r2_oob = r2_score(y_train, model.oob_prediction_)

    # Print and return results
    print(f"Final Random Forest Model for {target_column}")
    print(f"Test RMSE: {rmse_test:.4f}, Test R^2: {r2_test:.4f}")
    print(f"OOB RMSE (Training): {rmse_oob:.4f}, OOB R^2 (Training): {r2_oob:.4f}")

    return {
        'Test RMSE': rmse_test,
        'Test R^2': r2_test,
        'OOB RMSE (Training)': rmse_oob,
        'OOB R^2 (Training)': r2_oob
    }

# Run final Random Forest model on Fog RFL data
print("Evaluating final model for Fog Weather - RFL subset")
fog_rfl_final_results = final_random_forest_model(fog_rfl_data, target_column='RFL_Att')

# Run final Random Forest model on Fog FSO data
print("\nEvaluating final model for Fog Weather - FSO subset")
fog_fso_final_results = final_random_forest_model(fog_fso_data, target_column='FSO_Att')
# Out:
# Evaluating final model for Fog Weather - RFL subset
# Final Random Forest Model for RFL_Att
# Test RMSE: 0.4907, Test R^2: 0.9239
# OOB RMSE (Training): 0.5134, OOB R^2 (Training): 0.8963
#
# Evaluating final model for Fog Weather - FSO subset
# Final Random Forest Model for FSO_Att
# Test RMSE: 0.6350, Test R^2: 0.9727
# OOB RMSE (Training): 0.7342, OOB R^2 (Training): 0.9658

# %%
import pandas as pd

def calculate_feature_importance_differences(results_df, full_model_results):
    # Calculate the absolute differences in RMSE and R^2 between training (OOB) and test datasets
    results_df['RMSE Difference'] = abs(full_model_results['OOB RMSE (Training)'] - results_df['RMSE'])
    results_df['R^2 Difference'] = abs(full_model_results['OOB R^2 (Training)'] - results_df['R^2'])
    
    # Rank features by importance based on the sum of RMSE and R^2 differences
    results_df['Importance Score'] = results_df['RMSE Difference'] + results_df['R^2 Difference']
    
    # Sort by importance score in descending order
    results_df = results_df.sort_values(by='Importance Score', ascending=False).reset_index(drop=True)
    
    return results_df[['Removed Feature', 'RMSE Difference', 'R^2 Difference', 'Importance Score']]

# Example usage:
print("Calculating feature importance for Fog Weather - RFL subset")
fog_rfl_importance = calculate_feature_importance_differences(fog_rfl_results, fog_rfl_final_results)
print(fog_rfl_importance)

print("\nCalculating feature importance for Fog Weather - FSO subset")
fog_fso_importance = calculate_feature_importance_differences(fog_fso_results, fog_fso_final_results)
print(fog_fso_importance)
# Out:
# Calculating feature importance for Fog Weather - RFL subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0                Distance         0.029473        0.029666          0.059139
# 1             Particulate         0.025085        0.028319          0.053404
# 2          ParticulateMax         0.024447        0.028122          0.052568
# 3          ParticulateMin         0.022473        0.027511          0.049983
# 4     AbsoluteHumidityMax         0.022328        0.027466          0.049794
# 5                    Time         0.021011        0.027057          0.048068
# 6               WindSpeed         0.019315        0.026528          0.045843
# 7        RainIntensityMax         0.018643        0.026318          0.044961
# 8              Visibility         0.018491        0.026271          0.044761
# 9        AbsoluteHumidity         0.018473        0.026265          0.044738
# 10       RainIntensityMin         0.017618        0.025998          0.043616
# 11          RainIntensity         0.017345        0.025912          0.043257
# 12          VisibilityMax         0.017228        0.025875          0.043103
# 13          VisibilityMin         0.016470        0.025638          0.042108
# 14            Temperature         0.016096        0.025520          0.041616
# 15       RelativeHumidity         0.014941        0.025157          0.040098
# 16           WindSpeedMax         0.014886        0.025140          0.040026
# 17           WindSpeedMin         0.014550        0.025034          0.039584
# 18          WindDirection         0.013789        0.024793          0.038582
# 19         TemperatureMax         0.013704        0.024767          0.038471
# 20         TemperatureMin         0.009938        0.023573          0.033511
# 21  TemperatureDifference         0.009878        0.023554          0.033432
# 22    AbsoluteHumidityMin         0.003041        0.021364          0.024405
# 23              Frequency         0.001002        0.020706          0.021708
#
# Calculating feature importance for Fog Weather - FSO subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0          ParticulateMax         0.139698        0.010221          0.149919
# 1     AbsoluteHumidityMin         0.127806        0.009253          0.137059
# 2           WindDirection         0.126424        0.009139          0.135563
# 3               WindSpeed         0.125560        0.009068          0.134628
# 4             Temperature         0.124822        0.009007          0.133829
# 5            WindSpeedMax         0.124820        0.009007          0.133827
# 6        RelativeHumidity         0.122634        0.008826          0.131460
# 7            WindSpeedMin         0.120067        0.008612          0.128680
# 8          TemperatureMax         0.120043        0.008610          0.128653
# 9        AbsoluteHumidity         0.119802        0.008590          0.128392
# 10         ParticulateMin         0.116738        0.008334          0.125072
# 11          VisibilityMin         0.116726        0.008333          0.125060
# 12         TemperatureMin         0.113766        0.008085          0.121851
# 13          VisibilityMax         0.112414        0.007971          0.120385
# 14    AbsoluteHumidityMax         0.110510        0.007810          0.118320
# 15          RainIntensity         0.110510        0.007810          0.118320
# 16              Frequency         0.110073        0.007773          0.117846
# 17       RainIntensityMin         0.109915        0.007760          0.117675
# 18       RainIntensityMax         0.108430        0.007634          0.116064
# 19             Visibility         0.106470        0.007467          0.113938
# 20            Particulate         0.095071        0.006488          0.101559
# 21  TemperatureDifference         0.083160        0.005446          0.088606
# 22                   Time         0.012171        0.003589          0.015760
# 23               Distance         0.012144        0.003586          0.015730

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

def iterative_feature_removal(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]
    
    # Prepare a DataFrame to store the results
    results = pd.DataFrame(columns=['Remaining Features', 'OOB RMSE', 'OOB R^2'])

    # Initialize the list of features to be removed iteratively
    remaining_features = list(predictors.columns)

    while remaining_features:
        # Train the Random Forest model with current set of features
        model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
        model.fit(predictors[remaining_features], target)

        # Calculate OOB RMSE and R^2
        oob_predictions = model.oob_prediction_
        oob_rmse = np.sqrt(mean_squared_error(target, oob_predictions))
        oob_r2 = r2_score(target, oob_predictions)

        # Record the current state
        result_row = pd.DataFrame({
            'Remaining Features': [remaining_features.copy()],
            'OOB RMSE': [oob_rmse],
            'OOB R^2': [oob_r2]
        })
        results = pd.concat([results, result_row], ignore_index=True)

        # Rank features by importance and remove the least important feature
        importances = model.feature_importances_
        least_important_feature = remaining_features[np.argmin(importances)]
        remaining_features.remove(least_important_feature)
        
        # Print the step results
        print(f"Features: {remaining_features}")
        print(f"OOB RMSE: {oob_rmse:.4f}, OOB R^2: {oob_r2:.4f}")
        print(f"Removed Feature: {least_important_feature}\n")
    
    return results

# Run iterative feature removal on Fog RFL subset
print("Iterative feature removal for Fog Weather - RFL subset")
fog_rfl_removal_results = iterative_feature_removal(fog_rfl_data, target_column='RFL_Att')

# Run iterative feature removal on Fog FSO subset
print("\nIterative feature removal for Fog Weather - FSO subset")
fog_fso_removal_results = iterative_feature_removal(fog_fso_data, target_column='FSO_Att')
# Out:
# Iterative feature removal for Fog Weather - RFL subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4680\138420937.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.4577, OOB R^2: 0.9245
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeedMax']
# OOB RMSE: 0.4543, OOB R^2: 0.9257
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeedMax']
# OOB RMSE: 0.4588, OOB R^2: 0.9242
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.4595, OOB R^2: 0.9240
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.4604, OOB R^2: 0.9237
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.4571, OOB R^2: 0.9248
# Removed Feature: TemperatureDifference
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.4593, OOB R^2: 0.9240
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.4509, OOB R^2: 0.9268
# Removed Feature: Time
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.4506, OOB R^2: 0.9269
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.4511, OOB R^2: 0.9267
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.4759, OOB R^2: 0.9184
# Removed Feature: VisibilityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.4829, OOB R^2: 0.9160
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMin']
# OOB RMSE: 0.4690, OOB R^2: 0.9208
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Visibility']
# OOB RMSE: 0.4770, OOB R^2: 0.9181
# Removed Feature: VisibilityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureMax', 'TemperatureMin', 'Visibility']
# OOB RMSE: 0.4808, OOB R^2: 0.9167
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureMin', 'Visibility']
# OOB RMSE: 0.4747, OOB R^2: 0.9188
# Removed Feature: TemperatureMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureMin']
# OOB RMSE: 0.4685, OOB R^2: 0.9210
# Removed Feature: Visibility
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureMin']
# OOB RMSE: 0.5054, OOB R^2: 0.9080
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureMin']
# OOB RMSE: 0.5038, OOB R^2: 0.9086
# Removed Feature: AbsoluteHumidity
#
# Features: ['AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMin', 'RelativeHumidity']
# OOB RMSE: 0.5131, OOB R^2: 0.9052
# Removed Feature: TemperatureMin
#
# Features: ['AbsoluteHumidityMin', 'RainIntensityMin', 'RelativeHumidity']
# OOB RMSE: 0.5510, OOB R^2: 0.8907
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidityMin', 'RelativeHumidity']
# OOB RMSE: 0.5499, OOB R^2: 0.8911
# Removed Feature: RainIntensityMin
#
# Features: ['RelativeHumidity']
# OOB RMSE: 0.9235, OOB R^2: 0.6929
# Removed Feature: AbsoluteHumidityMin
#
# Features: []
# OOB RMSE: 1.2384, OOB R^2: 0.4478
# Removed Feature: RelativeHumidity
#
#
# Iterative feature removal for Fog Weather - FSO subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4680\138420937.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.6087, OOB R^2: 0.9762
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.6081, OOB R^2: 0.9763
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.6178, OOB R^2: 0.9755
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.6093, OOB R^2: 0.9762
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.6083, OOB R^2: 0.9762
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.5946, OOB R^2: 0.9773
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.6116, OOB R^2: 0.9760
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.5930, OOB R^2: 0.9774
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.5936, OOB R^2: 0.9774
# Removed Feature: WindSpeed
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.6080, OOB R^2: 0.9763
# Removed Feature: AbsoluteHumidity
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.6034, OOB R^2: 0.9766
# Removed Feature: VisibilityMax
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.6014, OOB R^2: 0.9768
# Removed Feature: TemperatureDifference
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 0.6347, OOB R^2: 0.9741
# Removed Feature: VisibilityMin
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 0.6427, OOB R^2: 0.9735
# Removed Feature: RelativeHumidity
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMin', 'Time', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 0.6256, OOB R^2: 0.9749
# Removed Feature: TemperatureMax
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMin', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 0.6122, OOB R^2: 0.9759
# Removed Feature: Time
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureMin', 'Visibility']
# OOB RMSE: 0.6791, OOB R^2: 0.9704
# Removed Feature: WindSpeedMax
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'Visibility']
# OOB RMSE: 0.7252, OOB R^2: 0.9662
# Removed Feature: TemperatureMin
#
# Features: ['Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature']
# OOB RMSE: 0.7500, OOB R^2: 0.9639
# Removed Feature: Visibility
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature']
# OOB RMSE: 1.2151, OOB R^2: 0.9052
# Removed Feature: Distance
#
# Features: ['Particulate', 'ParticulateMin', 'Temperature']
# OOB RMSE: 1.2831, OOB R^2: 0.8943
# Removed Feature: ParticulateMax
#
# Features: ['Particulate', 'ParticulateMin']
# OOB RMSE: 1.2693, OOB R^2: 0.8966
# Removed Feature: Temperature
#
# Features: ['Particulate']
# OOB RMSE: 2.2206, OOB R^2: 0.6834
# Removed Feature: ParticulateMin
#
# Features: []
# OOB RMSE: 2.3005, OOB R^2: 0.6602
# Removed Feature: Particulate

# %%
print(fog_rfl_removal_results.columns)
# Out:
# Index(['Remaining Features', 'OOB RMSE', 'OOB R^2'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def add_removed_feature_column(results_df):
    # Extract all features in the initial (first row) 'Remaining Features' column
    all_features = set(results_df['Remaining Features'].iloc[0])
    
    # Initialize a list to store removed features
    removed_features = []
    
    # Set to track already removed features
    remaining_features = all_features.copy()

    # Compute removed features at each step
    for i in range(len(results_df)):
        current_features = set(results_df['Remaining Features'].iloc[i])
        removed = list(remaining_features - current_features)
        
        # Add the removed feature to the list, and remove it from the remaining features set
        if removed:
            removed_feature = removed[0]
            removed_features.append(removed_feature)
            remaining_features.remove(removed_feature)
        else:
            removed_features.append(None)  # No feature removed (last step)

    # Add the new column to the DataFrame
    results_df['Removed Feature'] = removed_features
    return results_df

# Update results DataFrames to include 'Removed Feature'
fog_rfl_removal_results = add_removed_feature_column(fog_rfl_removal_results)
fog_fso_removal_results = add_removed_feature_column(fog_fso_removal_results)

def plot_rmse_r2(results_df, title):
    # Verify columns exist
    expected_columns = ['OOB RMSE', 'OOB R^2', 'Removed Feature']
    for col in expected_columns:
        if col not in results_df.columns:
            raise KeyError(f"Expected column '{col}' not found in DataFrame.")

    # Extract RMSE, R^2 values, and removed features
    rmse_values = results_df['OOB RMSE']
    r2_values = results_df['OOB R^2']
    features_removed = range(len(results_df))
    removed_feature_names = results_df['Removed Feature']

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    ax1.plot(features_removed, rmse_values, color="blue", marker="o", label="RMSE")
    ax1.set_xlabel("Features Removed")
    ax1.set_ylabel("RMSE (dB)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(features_removed, r2_values, color="orange", marker="o", label="R^2")
    ax2.set_ylabel("R^2", color="orange")
    ax2.tick_params(axis="y", labelcolor="orange")

    # Place the removed feature names horizontally under the x-axis
    ax1.set_xticks(features_removed)
    ax1.set_xticklabels(removed_feature_names, rotation=90, ha='center', fontsize=8, color="black")

    separation_point = len(results_df) - 10
    ax1.axvline(x=separation_point, color="green", linestyle="--", label="Important Feature Separation")

    plt.title(title)
    fig.tight_layout()
    fig.legend(loc="upper right")
    plt.show()

# Plot updated DataFrames with removed feature names under the x-axis in order of removal
plot_rmse_r2(fog_rfl_removal_results, "Fog Weather - RFL")
plot_rmse_r2(fog_fso_removal_results, "Fog Weather - FSO")

# %%
#  Identify features to the right of the green line
def get_important_features(results_df, separation_point):
    # Get the features from the green line to the end of the list
    important_features = results_df['Removed Feature'][separation_point:].dropna().tolist()
    return important_features

# Train Random Forest on selected features
def train_random_forest_on_important_features(data, target_column, important_features):
    # Subset the data to include only the important features
    X = data[important_features]
    y = data[target_column]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X, y)

    # Calculate RMSE and R^2 on OOB (Out-of-Bag) predictions
    oob_predictions = model.oob_prediction_
    rmse = np.sqrt(mean_squared_error(y, oob_predictions))
    r2 = r2_score(y, oob_predictions)
    
    return rmse, r2, model

# Define the separation point (assuming last 10 features are considered important)
separation_point = len(fog_rfl_removal_results) - 10

# Get important features based on the green line separation for both RFL and FSO
important_features_rfl = get_important_features(fog_rfl_removal_results, separation_point)
important_features_fso = get_important_features(fog_fso_removal_results, separation_point)

#  Train and evaluate the model for RFL
rmse_rfl, r2_rfl, model_rfl = train_random_forest_on_important_features(data, 'RFL_Att', important_features_rfl)
print(f"RFL Model - RMSE: {rmse_rfl:.4f}, R^2: {r2_rfl:.4f}")

# Train and evaluate the model for FSO
rmse_fso, r2_fso, model_fso = train_random_forest_on_important_features(data, 'FSO_Att', important_features_fso)
print(f"FSO Model - RMSE: {rmse_fso:.4f}, R^2: {r2_fso:.4f}")
# Out:
# RFL Model - RMSE: 1.3231, R^2: 0.8520
# FSO Model - RMSE: 0.8235, R^2: 0.9555
