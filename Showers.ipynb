# %%
import pandas as pd

# Load the dataset 
file_path = r"C:\Users\punee\Downloads\Aditi coding\RFLFSODataFull.csv"
data = pd.read_csv(file_path)

# Creating separate data subsets for each weather condition
clear_data = data[data['SYNOPCode'] == 0]      
dust_storm_data = data[data['SYNOPCode'] == 3] 
fog_data = data[data['SYNOPCode'] == 4]         
drizzle_data = data[data['SYNOPCode'] == 5]    
rain_data = data[data['SYNOPCode'] == 6]        
snow_data = data[data['SYNOPCode'] == 7]        
showers_data = data[data['SYNOPCode'] == 8]    

# Verify the size of each subset 
print("Number of entries in each subset:")
print("Clear:", len(clear_data))
print("Dust Storm:", len(dust_storm_data))
print("Fog:", len(fog_data))
print("Drizzle:", len(drizzle_data))
print("Rain:", len(rain_data))
print("Snow:", len(snow_data))
print("Showers:", len(showers_data))
# Out:
# Number of entries in each subset:
# Clear: 56964
# Dust Storm: 191
# Fog: 466
# Drizzle: 6605
# Rain: 25018
# Snow: 419
# Showers: 1716

# %%
# Filter the data to get only the "Showers" weather condition 
showers_data = data[data['SYNOPCode'] == 8]
# Filter rows with RFL data (where 'RFL_Att' has values)
showers_rfl_data = showers_data.dropna(subset=['RFL_Att'])

# Filter rows with FSO data (where 'FSO_Att' has values)
showers_fso_data = showers_data.dropna(subset=['FSO_Att'])

# Verify the sizes of each subset
print("Number of entries in Showers (RFL):", len(showers_rfl_data))
print("Number of entries in Showers (FSO):", len(showers_fso_data))
# Out:
# Number of entries in Showers (RFL): 1716
# Number of entries in Showers (FSO): 1716

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Assuming you have already run Step 1 and created showers_rfl_data and showers_fso_data

def evaluate_models(data, target_column):
    # Drop columns that are not predictors (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Set the target column, either 'RFL_Att' or 'FSO_Att'
    
    # Prepare to store RMSE and R^2 scores for each feature removed
    rmse_scores = []
    r2_scores = []
    removed_features = []

    # Loop through each column, removing it and training a model
    for feature in predictors.columns:
        # Drop the feature from the predictors
        predictors_subset = predictors.drop(columns=[feature])
        
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(predictors_subset, target, test_size=0.3, random_state=42)
        
        # Train a Random Forest model
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)
        
        # Predictions on test data
        y_pred = model.predict(X_test)
        
        # Calculate RMSE and R^2
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store the results
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        removed_features.append(feature)
        
        # Print results for each model
        print(f"Feature removed: {feature}")
        print(f"RMSE: {rmse:.4f}, R^2: {r2:.4f}")
    
    # Store the results in a DataFrame for easier handling
    results_df = pd.DataFrame({
        'Removed Feature': removed_features,
        'RMSE': rmse_scores,
        'R^2': r2_scores
    })
    
    return results_df

# Run evaluation on Showers RFL data
print("Evaluating models for Showers Weather - RFL subset")
showers_rfl_results = evaluate_models(showers_rfl_data, target_column='RFL_Att')

# Run evaluation on Showers FSO data
print("\nEvaluating models for Showers Weather - FSO subset")
showers_fso_results = evaluate_models(showers_fso_data, target_column='FSO_Att')
# Out:
# Evaluating models for Showers Weather - RFL subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.9846, R^2: 0.8865
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.9793, R^2: 0.8878
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.9954, R^2: 0.8840
# Feature removed: Distance
# RMSE: 1.0598, R^2: 0.8685
# Feature removed: Frequency
# RMSE: 1.1016, R^2: 0.8580
# Feature removed: Particulate
# RMSE: 1.0018, R^2: 0.8825
# Feature removed: ParticulateMax
# RMSE: 0.9942, R^2: 0.8843
# Feature removed: ParticulateMin
# RMSE: 0.9973, R^2: 0.8836
# Feature removed: RainIntensity
# RMSE: 1.0005, R^2: 0.8828
# Feature removed: RainIntensityMax
# RMSE: 0.9903, R^2: 0.8852
# Feature removed: RainIntensityMin
# RMSE: 0.9848, R^2: 0.8865
# Feature removed: RelativeHumidity
# RMSE: 1.0070, R^2: 0.8813
# Feature removed: Temperature
# RMSE: 0.9738, R^2: 0.8890
# Feature removed: TemperatureDifference
# RMSE: 1.0079, R^2: 0.8811
# Feature removed: TemperatureMax
# RMSE: 0.9989, R^2: 0.8832
# Feature removed: TemperatureMin
# RMSE: 1.0139, R^2: 0.8797
# Feature removed: Time
# RMSE: 1.0003, R^2: 0.8829
# Feature removed: Visibility
# RMSE: 1.0034, R^2: 0.8822
# Feature removed: VisibilityMax
# RMSE: 0.9968, R^2: 0.8837
# Feature removed: VisibilityMin
# RMSE: 1.0052, R^2: 0.8817
# Feature removed: WindDirection
# RMSE: 0.9835, R^2: 0.8868
# Feature removed: WindSpeed
# RMSE: 1.0032, R^2: 0.8822
# Feature removed: WindSpeedMax
# RMSE: 1.0010, R^2: 0.8827
# Feature removed: WindSpeedMin
# RMSE: 0.9961, R^2: 0.8839
#
# Evaluating models for Showers Weather - FSO subset
# Feature removed: AbsoluteHumidity
# RMSE: 1.0276, R^2: 0.9242
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.9953, R^2: 0.9289
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.9958, R^2: 0.9288
# Feature removed: Distance
# RMSE: 1.0331, R^2: 0.9234
# Feature removed: Frequency
# RMSE: 0.9968, R^2: 0.9286
# Feature removed: Particulate
# RMSE: 1.0103, R^2: 0.9267
# Feature removed: ParticulateMax
# RMSE: 1.0106, R^2: 0.9267
# Feature removed: ParticulateMin
# RMSE: 1.0060, R^2: 0.9273
# Feature removed: RainIntensity
# RMSE: 1.0055, R^2: 0.9274
# Feature removed: RainIntensityMax
# RMSE: 1.0056, R^2: 0.9274
# Feature removed: RainIntensityMin
# RMSE: 1.0046, R^2: 0.9275
# Feature removed: RelativeHumidity
# RMSE: 1.1003, R^2: 0.9131
# Feature removed: Temperature
# RMSE: 1.0254, R^2: 0.9245
# Feature removed: TemperatureDifference
# RMSE: 1.0291, R^2: 0.9239
# Feature removed: TemperatureMax
# RMSE: 0.9998, R^2: 0.9282
# Feature removed: TemperatureMin
# RMSE: 0.9821, R^2: 0.9307
# Feature removed: Time
# RMSE: 1.0453, R^2: 0.9215
# Feature removed: Visibility
# RMSE: 0.9947, R^2: 0.9289
# Feature removed: VisibilityMax
# RMSE: 0.9921, R^2: 0.9293
# Feature removed: VisibilityMin
# RMSE: 0.9893, R^2: 0.9297
# Feature removed: WindDirection
# RMSE: 0.9926, R^2: 0.9292
# Feature removed: WindSpeed
# RMSE: 1.0074, R^2: 0.9271
# Feature removed: WindSpeedMax
# RMSE: 1.0071, R^2: 0.9272
# Feature removed: WindSpeedMin
# RMSE: 1.0055, R^2: 0.9274

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def final_random_forest_model(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Target is either 'RFL_Att' or 'FSO_Att'

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

    # Train a Random Forest model using all features
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X_train, y_train)

    # Predictions on test data
    y_pred = model.predict(X_test)

    # Calculate RMSE and R^2 for test data
    rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_test = r2_score(y_test, y_pred)

    # Calculate OOB RMSE and R^2 (training data) for comparison
    rmse_oob = np.sqrt(mean_squared_error(y_train, model.oob_prediction_))
    r2_oob = r2_score(y_train, model.oob_prediction_)

    # Print and return results
    print(f"Final Random Forest Model for {target_column}")
    print(f"Test RMSE: {rmse_test:.4f}, Test R^2: {r2_test:.4f}")
    print(f"OOB RMSE (Training): {rmse_oob:.4f}, OOB R^2 (Training): {r2_oob:.4f}")

    return {
        'Test RMSE': rmse_test,
        'Test R^2': r2_test,
        'OOB RMSE (Training)': rmse_oob,
        'OOB R^2 (Training)': r2_oob
    }

# Run final Random Forest model on Showers RFL data
print("Evaluating final model for Showers Weather - RFL subset")
showers_rfl_final_results = final_random_forest_model(showers_rfl_data, target_column='RFL_Att')

# Run final Random Forest model on Showers FSO data
print("\nEvaluating final model for Showers Weather - FSO subset")
showers_fso_final_results = final_random_forest_model(showers_fso_data, target_column='FSO_Att')
# Out:
# Evaluating final model for Showers Weather - RFL subset
# Final Random Forest Model for RFL_Att
# Test RMSE: 1.0042, Test R^2: 0.8820
# OOB RMSE (Training): 1.0175, OOB R^2 (Training): 0.8950
#
# Evaluating final model for Showers Weather - FSO subset
# Final Random Forest Model for FSO_Att
# Test RMSE: 0.9984, Test R^2: 0.9284
# OOB RMSE (Training): 1.1079, OOB R^2 (Training): 0.9260

# %%
import pandas as pd

def calculate_feature_importance_differences(results_df, full_model_results):
    # Calculate the absolute differences in RMSE and R^2 between training (OOB) and test datasets
    results_df['RMSE Difference'] = abs(full_model_results['OOB RMSE (Training)'] - results_df['RMSE'])
    results_df['R^2 Difference'] = abs(full_model_results['OOB R^2 (Training)'] - results_df['R^2'])
    
    # Rank features by importance based on the sum of RMSE and R^2 differences
    results_df['Importance Score'] = results_df['RMSE Difference'] + results_df['R^2 Difference']
    
    # Sort by importance score in descending order
    results_df = results_df.sort_values(by='Importance Score', ascending=False).reset_index(drop=True)
    
    return results_df[['Removed Feature', 'RMSE Difference', 'R^2 Difference', 'Importance Score']]

# Example usage:
print("Calculating feature importance for Showers Weather - RFL subset")
showers_rfl_importance = calculate_feature_importance_differences(showers_rfl_results, showers_rfl_final_results)
print(showers_rfl_importance)

print("\nCalculating feature importance for Showers Weather - FSO subset")
showers_fso_importance = calculate_feature_importance_differences(showers_fso_results, showers_fso_final_results)
print(showers_fso_importance)
# Out:
# Calculating feature importance for Showers Weather - RFL subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0               Frequency         0.084076        0.037029          0.121105
# 1                Distance         0.042313        0.026464          0.068777
# 2             Temperature         0.043699        0.005990          0.049689
# 3     AbsoluteHumidityMax         0.038239        0.007239          0.045477
# 4           WindDirection         0.034076        0.008195          0.042270
# 5        AbsoluteHumidity         0.032879        0.008471          0.041349
# 6        RainIntensityMin         0.032700        0.008512          0.041212
# 7        RainIntensityMax         0.027263        0.009769          0.037032
# 8          ParticulateMax         0.023349        0.010678          0.034027
# 9     AbsoluteHumidityMin         0.022129        0.010962          0.033091
# 10           WindSpeedMin         0.021414        0.011129          0.032542
# 11          VisibilityMax         0.020739        0.011286          0.032025
# 12         ParticulateMin         0.020201        0.011411          0.031613
# 13         TemperatureMax         0.018670        0.011769          0.030439
# 14                   Time         0.017231        0.012106          0.029337
# 15          RainIntensity         0.016993        0.012162          0.029155
# 16           WindSpeedMax         0.016558        0.012264          0.028821
# 17            Particulate         0.015721        0.012460          0.028181
# 18              WindSpeed         0.014361        0.012779          0.027140
# 19             Visibility         0.014174        0.012823          0.026997
# 20          VisibilityMin         0.012318        0.013259          0.025577
# 21       RelativeHumidity         0.010568        0.013671          0.024240
# 22  TemperatureDifference         0.009639        0.013890          0.023529
# 23         TemperatureMin         0.003671        0.015303          0.018974
#
# Calculating feature importance for Showers Weather - FSO subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0          TemperatureMin         0.125800        0.004742          0.130541
# 1           VisibilityMin         0.118667        0.003732          0.122399
# 2           VisibilityMax         0.115876        0.003335          0.119211
# 3           WindDirection         0.115308        0.003254          0.118561
# 4              Visibility         0.113240        0.002959          0.116199
# 5     AbsoluteHumidityMax         0.112635        0.002872          0.115507
# 6     AbsoluteHumidityMin         0.112164        0.002805          0.114969
# 7               Frequency         0.111143        0.002659          0.113802
# 8          TemperatureMax         0.108171        0.002233          0.110404
# 9        RainIntensityMin         0.103332        0.001536          0.104869
# 10           WindSpeedMin         0.102476        0.001412          0.103888
# 11          RainIntensity         0.102470        0.001412          0.103882
# 12       RainIntensityMax         0.102354        0.001395          0.103749
# 13         ParticulateMin         0.101959        0.001338          0.103297
# 14           WindSpeedMax         0.100852        0.001178          0.102030
# 15              WindSpeed         0.100587        0.001139          0.101726
# 16            Particulate         0.097666        0.000716          0.098383
# 17         ParticulateMax         0.097321        0.000666          0.097987
# 18            Temperature         0.082558        0.001492          0.084050
# 19       AbsoluteHumidity         0.080376        0.001814          0.082190
# 20  TemperatureDifference         0.078859        0.002038          0.080897
# 21               Distance         0.074882        0.002627          0.077509
# 22                   Time         0.062642        0.004454          0.067096
# 23       RelativeHumidity         0.007682        0.012922          0.020605

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

def iterative_feature_removal(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]
    
    # Prepare a DataFrame to store the results
    results = pd.DataFrame(columns=['Remaining Features', 'OOB RMSE', 'OOB R^2'])

    # Initialize the list of features to be removed iteratively
    remaining_features = list(predictors.columns)

    while remaining_features:
        # Train the Random Forest model with current set of features
        model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
        model.fit(predictors[remaining_features], target)

        # Calculate OOB RMSE and R^2
        oob_predictions = model.oob_prediction_
        oob_rmse = np.sqrt(mean_squared_error(target, oob_predictions))
        oob_r2 = r2_score(target, oob_predictions)

        # Record the current state
        result_row = pd.DataFrame({
            'Remaining Features': [remaining_features.copy()],
            'OOB RMSE': [oob_rmse],
            'OOB R^2': [oob_r2]
        })
        results = pd.concat([results, result_row], ignore_index=True)

        # Rank features by importance and remove the least important feature
        importances = model.feature_importances_
        least_important_feature = remaining_features[np.argmin(importances)]
        remaining_features.remove(least_important_feature)
        
        # Print the step results
        print(f"Features: {remaining_features}")
        print(f"OOB RMSE: {oob_rmse:.4f}, OOB R^2: {oob_r2:.4f}")
        print(f"Removed Feature: {least_important_feature}\n")
    
    return results

# Run iterative feature removal on Showers RFL subset
print("Iterative feature removal for Showers Weather - RFL subset")
showers_rfl_removal_results = iterative_feature_removal(showers_rfl_data, target_column='RFL_Att')

# Run iterative feature removal on Showers FSO subset
print("\nIterative feature removal for Showers Weather - FSO subset")
showers_fso_removal_results = iterative_feature_removal(showers_fso_data, target_column='FSO_Att')
# Out:
# Iterative feature removal for Showers Weather - RFL subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4284\1995795187.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8954, OOB R^2: 0.9153
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8964, OOB R^2: 0.9151
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8880, OOB R^2: 0.9167
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8787, OOB R^2: 0.9184
# Removed Feature: Time
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8910, OOB R^2: 0.9161
# Removed Feature: TemperatureMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed']
# OOB RMSE: 0.8908, OOB R^2: 0.9162
# Removed Feature: TemperatureMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8816, OOB R^2: 0.9179
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'TemperatureDifference', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8794, OOB R^2: 0.9183
# Removed Feature: RelativeHumidity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'TemperatureDifference', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8867, OOB R^2: 0.9169
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.0623, OOB R^2: 0.8808
# Removed Feature: TemperatureDifference
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.1065, OOB R^2: 0.8706
# Removed Feature: VisibilityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.1096, OOB R^2: 0.8699
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Temperature', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.0997, OOB R^2: 0.8722
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.1481, OOB R^2: 0.8607
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.1702, OOB R^2: 0.8553
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'VisibilityMin']
# OOB RMSE: 1.1723, OOB R^2: 0.8548
# Removed Feature: Visibility
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'ParticulateMin', 'RainIntensity', 'RainIntensityMin', 'VisibilityMin']
# OOB RMSE: 1.1795, OOB R^2: 0.8530
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'RainIntensity', 'RainIntensityMin', 'VisibilityMin']
# OOB RMSE: 1.1791, OOB R^2: 0.8531
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'RainIntensity', 'RainIntensityMin', 'VisibilityMin']
# OOB RMSE: 1.1731, OOB R^2: 0.8546
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'RainIntensity', 'RainIntensityMin']
# OOB RMSE: 1.1569, OOB R^2: 0.8586
# Removed Feature: VisibilityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'RainIntensity']
# OOB RMSE: 1.3512, OOB R^2: 0.8071
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'RainIntensity']
# OOB RMSE: 1.3566, OOB R^2: 0.8056
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity']
# OOB RMSE: 1.4146, OOB R^2: 0.7886
# Removed Feature: RainIntensity
#
# Features: []
# OOB RMSE: 2.5641, OOB R^2: 0.3054
# Removed Feature: AbsoluteHumidity
#
#
# Iterative feature removal for Showers Weather - FSO subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4284\1995795187.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8611, OOB R^2: 0.9530
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.8756, OOB R^2: 0.9514
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8623, OOB R^2: 0.9529
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8647, OOB R^2: 0.9526
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensityMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8591, OOB R^2: 0.9533
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8551, OOB R^2: 0.9537
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.8554, OOB R^2: 0.9537
# Removed Feature: TemperatureMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.8373, OOB R^2: 0.9556
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8332, OOB R^2: 0.9560
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8742, OOB R^2: 0.9516
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8703, OOB R^2: 0.9520
# Removed Feature: TemperatureMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'RelativeHumidity', 'Temperature', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8571, OOB R^2: 0.9535
# Removed Feature: TemperatureDifference
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'RelativeHumidity', 'Temperature', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8929, OOB R^2: 0.9495
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'RelativeHumidity', 'Temperature', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.9017, OOB R^2: 0.9485
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'RelativeHumidity', 'Temperature', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.8861, OOB R^2: 0.9503
# Removed Feature: Time
#
# Features: ['AbsoluteHumidity', 'Distance', 'Particulate', 'RelativeHumidity', 'Temperature', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.9457, OOB R^2: 0.9433
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidity', 'Distance', 'RelativeHumidity', 'Temperature', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.9286, OOB R^2: 0.9454
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'Distance', 'RelativeHumidity', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.9759, OOB R^2: 0.9397
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidity', 'Distance', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.9983, OOB R^2: 0.9369
# Removed Feature: RelativeHumidity
#
# Features: ['AbsoluteHumidity', 'Distance', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.2098, OOB R^2: 0.9073
# Removed Feature: VisibilityMax
#
# Features: ['Distance', 'Visibility', 'VisibilityMin']
# OOB RMSE: 1.1952, OOB R^2: 0.9095
# Removed Feature: AbsoluteHumidity
#
# Features: ['Distance', 'Visibility']
# OOB RMSE: 1.8839, OOB R^2: 0.7752
# Removed Feature: VisibilityMin
#
# Features: ['Visibility']
# OOB RMSE: 1.8678, OOB R^2: 0.7790
# Removed Feature: Distance
#
# Features: []
# OOB RMSE: 2.8541, OOB R^2: 0.4840
# Removed Feature: Visibility

# %%
print(showers_rfl_removal_results.columns)
# Out:
# Index(['Remaining Features', 'OOB RMSE', 'OOB R^2'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def add_removed_feature_column(results_df):
    # Extract all features in the initial (first row) 'Remaining Features' column
    all_features = set(results_df['Remaining Features'].iloc[0])
    
    # Initialize a list to store removed features
    removed_features = []
    
    # Set to track already removed features
    remaining_features = all_features.copy()

    # Compute removed features at each step
    for i in range(len(results_df)):
        current_features = set(results_df['Remaining Features'].iloc[i])
        removed = list(remaining_features - current_features)
        
        # Add the removed feature to the list, and remove it from the remaining features set
        if removed:
            removed_feature = removed[0]
            removed_features.append(removed_feature)
            remaining_features.remove(removed_feature)
        else:
            removed_features.append(None)  # No feature removed (last step)

    # Add the new column to the DataFrame
    results_df['Removed Feature'] = removed_features
    return results_df

# Update results DataFrames to include 'Removed Feature'
showers_rfl_removal_results = add_removed_feature_column(showers_rfl_removal_results)
showers_fso_removal_results = add_removed_feature_column(showers_fso_removal_results)

def plot_rmse_r2(results_df, title):
    # Verify columns exist
    expected_columns = ['OOB RMSE', 'OOB R^2', 'Removed Feature']
    for col in expected_columns:
        if col not in results_df.columns:
            raise KeyError(f"Expected column '{col}' not found in DataFrame.")

    # Extract RMSE, R^2 values, and removed features
    rmse_values = results_df['OOB RMSE']
    r2_values = results_df['OOB R^2']
    features_removed = range(len(results_df))
    removed_feature_names = results_df['Removed Feature']

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    ax1.plot(features_removed, rmse_values, color="blue", marker="o", label="RMSE")
    ax1.set_xlabel("Features Removed")
    ax1.set_ylabel("RMSE (dB)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(features_removed, r2_values, color="orange", marker="o", label="R^2")
    ax2.set_ylabel("R^2", color="orange")
    ax2.tick_params(axis="y", labelcolor="orange")

    # Place the removed feature names horizontally under the x-axis
    ax1.set_xticks(features_removed)
    ax1.set_xticklabels(removed_feature_names, rotation=90, ha='center', fontsize=8, color="black")

    separation_point = len(results_df) - 10
    ax1.axvline(x=separation_point, color="green", linestyle="--", label="Important Feature Separation")

    plt.title(title)
    fig.tight_layout()
    fig.legend(loc="upper right")
    plt.show()

# Plot updated DataFrames with removed feature names under the x-axis in order of removal
plot_rmse_r2(showers_rfl_removal_results, "Showers Weather - RFL")
plot_rmse_r2(showers_fso_removal_results, "Showers Weather - FSO")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Identify features to the right of the green line
def get_important_features(results_df, separation_point):
    # Get the features from the green line to the end of the list
    important_features = results_df['Removed Feature'][separation_point:].dropna().tolist()
    return important_features

# Train Random Forest on selected features
def train_random_forest_on_important_features(data, target_column, important_features):
    # Subset the data to include only the important features
    X = data[important_features]
    y = data[target_column]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X, y)

    # Calculate RMSE and R^2 on OOB (Out-of-Bag) predictions
    oob_predictions = model.oob_prediction_
    rmse = np.sqrt(mean_squared_error(y, oob_predictions))
    r2 = r2_score(y, oob_predictions)
    
    return rmse, r2, model

# Define the separation point (assuming last 10 features are considered important)
separation_point = len(showers_rfl_removal_results) - 10

# Get important features based on the green line separation for both RFL and FSO
important_features_rfl = get_important_features(showers_rfl_removal_results, separation_point)
important_features_fso = get_important_features(showers_fso_removal_results, separation_point)

# Assume 'data' is your main dataset containing the predictor variables and the target column 'RFL_Att' for RFL subset and 'FSO_Att' for FSO subset.
# Replace 'data' with the appropriate variable name if it's different.

# Train and evaluate the model for RFL
rmse_rfl, r2_rfl, model_rfl = train_random_forest_on_important_features(data, 'RFL_Att', important_features_rfl)
print(f"RFL Model - RMSE: {rmse_rfl:.4f}, R^2: {r2_rfl:.4f}")

# Train and evaluate the model for FSO
rmse_fso, r2_fso, model_fso = train_random_forest_on_important_features(data, 'FSO_Att', important_features_fso)
print(f"FSO Model - RMSE: {rmse_fso:.4f}, R^2: {r2_fso:.4f}")
# Out:
# RFL Model - RMSE: 1.3661, R^2: 0.8422
# FSO Model - RMSE: 0.8477, R^2: 0.9529
