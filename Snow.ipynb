# %%
import pandas as pd

# Load the dataset 
file_path = r"C:\Users\punee\Downloads\Aditi coding\RFLFSODataFull.csv"
data = pd.read_csv(file_path)

# Creating separate data subsets for each weather condition
clear_data = data[data['SYNOPCode'] == 0]      
dust_storm_data = data[data['SYNOPCode'] == 3] 
fog_data = data[data['SYNOPCode'] == 4]         
drizzle_data = data[data['SYNOPCode'] == 5]    
rain_data = data[data['SYNOPCode'] == 6]        
snow_data = data[data['SYNOPCode'] == 7]        
showers_data = data[data['SYNOPCode'] == 8]    

# Verify the size of each subset 
print("Number of entries in each subset:")
print("Clear:", len(clear_data))
print("Dust Storm:", len(dust_storm_data))
print("Fog:", len(fog_data))
print("Drizzle:", len(drizzle_data))
print("Rain:", len(rain_data))
print("Snow:", len(snow_data))
print("Showers:", len(showers_data))
# Out:
# Number of entries in each subset:
# Clear: 56964
# Dust Storm: 191
# Fog: 466
# Drizzle: 6605
# Rain: 25018
# Snow: 419
# Showers: 1716

# %%
# Filter the data to get only the "Snow" weather condition 
snow_data = data[data['SYNOPCode'] == 7]
# Filter rows with RFL data (where 'RFL_Att' has values)
snow_rfl_data = snow_data.dropna(subset=['RFL_Att'])

# Filter rows with FSO data (where 'FSO_Att' has values)
snow_fso_data = snow_data.dropna(subset=['FSO_Att'])

# Verify the sizes of each subset
print("Number of entries in Snow (RFL):", len(snow_rfl_data))
print("Number of entries in Snow (FSO):", len(snow_fso_data))
# Out:
# Number of entries in Snow (RFL): 419
# Number of entries in Snow (FSO): 419

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Assuming you have already run Step 1 and created snow_rfl_data and snow_fso_data

def evaluate_models(data, target_column):
    # Drop columns that are not predictors (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Set the target column, either 'RFL_Att' or 'FSO_Att'
    
    # Prepare to store RMSE and R^2 scores for each feature removed
    rmse_scores = []
    r2_scores = []
    removed_features = []

    # Loop through each column, removing it and training a model
    for feature in predictors.columns:
        # Drop the feature from the predictors
        predictors_subset = predictors.drop(columns=[feature])
        
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(predictors_subset, target, test_size=0.3, random_state=42)
        
        # Train a Random Forest model
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)
        
        # Predictions on test data
        y_pred = model.predict(X_test)
        
        # Calculate RMSE and R^2
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store the results
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        removed_features.append(feature)
        
        # Print results for each model
        print(f"Feature removed: {feature}")
        print(f"RMSE: {rmse:.4f}, R^2: {r2:.4f}")
    
    # Store the results in a DataFrame for easier handling
    results_df = pd.DataFrame({
        'Removed Feature': removed_features,
        'RMSE': rmse_scores,
        'R^2': r2_scores
    })
    
    return results_df

# Run evaluation on Snow RFL data
print("Evaluating models for Snow Weather - RFL subset")
snow_rfl_results = evaluate_models(snow_rfl_data, target_column='RFL_Att')

# Run evaluation on Snow FSO data
print("\nEvaluating models for Snow Weather - FSO subset")
snow_fso_results = evaluate_models(snow_fso_data, target_column='FSO_Att')
# Out:
# Evaluating models for Snow Weather - RFL subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.2857, R^2: 0.9564
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.2949, R^2: 0.9535
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.2963, R^2: 0.9531
# Feature removed: Distance
# RMSE: 0.2934, R^2: 0.9540
# Feature removed: Frequency
# RMSE: 0.3409, R^2: 0.9379
# Feature removed: Particulate
# RMSE: 0.2899, R^2: 0.9551
# Feature removed: ParticulateMax
# RMSE: 0.2913, R^2: 0.9547
# Feature removed: ParticulateMin
# RMSE: 0.2910, R^2: 0.9547
# Feature removed: RainIntensity
# RMSE: 0.2997, R^2: 0.9520
# Feature removed: RainIntensityMax
# RMSE: 0.3064, R^2: 0.9498
# Feature removed: RainIntensityMin
# RMSE: 0.3008, R^2: 0.9517
# Feature removed: RelativeHumidity
# RMSE: 0.2961, R^2: 0.9532
# Feature removed: Temperature
# RMSE: 0.2964, R^2: 0.9531
# Feature removed: TemperatureDifference
# RMSE: 0.2825, R^2: 0.9573
# Feature removed: TemperatureMax
# RMSE: 0.3009, R^2: 0.9516
# Feature removed: TemperatureMin
# RMSE: 0.3033, R^2: 0.9508
# Feature removed: Time
# RMSE: 0.3102, R^2: 0.9486
# Feature removed: Visibility
# RMSE: 0.3008, R^2: 0.9516
# Feature removed: VisibilityMax
# RMSE: 0.3015, R^2: 0.9514
# Feature removed: VisibilityMin
# RMSE: 0.3007, R^2: 0.9517
# Feature removed: WindDirection
# RMSE: 0.2945, R^2: 0.9536
# Feature removed: WindSpeed
# RMSE: 0.2976, R^2: 0.9527
# Feature removed: WindSpeedMax
# RMSE: 0.3043, R^2: 0.9505
# Feature removed: WindSpeedMin
# RMSE: 0.2969, R^2: 0.9529
#
# Evaluating models for Snow Weather - FSO subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.9504, R^2: 0.9677
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.9332, R^2: 0.9689
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.9314, R^2: 0.9690
# Feature removed: Distance
# RMSE: 0.9445, R^2: 0.9681
# Feature removed: Frequency
# RMSE: 0.9432, R^2: 0.9682
# Feature removed: Particulate
# RMSE: 0.9515, R^2: 0.9676
# Feature removed: ParticulateMax
# RMSE: 0.9309, R^2: 0.9690
# Feature removed: ParticulateMin
# RMSE: 0.9335, R^2: 0.9688
# Feature removed: RainIntensity
# RMSE: 0.9480, R^2: 0.9679
# Feature removed: RainIntensityMax
# RMSE: 0.9413, R^2: 0.9683
# Feature removed: RainIntensityMin
# RMSE: 0.9446, R^2: 0.9681
# Feature removed: RelativeHumidity
# RMSE: 0.9809, R^2: 0.9656
# Feature removed: Temperature
# RMSE: 0.9562, R^2: 0.9673
# Feature removed: TemperatureDifference
# RMSE: 1.0736, R^2: 0.9588
# Feature removed: TemperatureMax
# RMSE: 0.9531, R^2: 0.9675
# Feature removed: TemperatureMin
# RMSE: 0.9604, R^2: 0.9670
# Feature removed: Time
# RMSE: 0.9614, R^2: 0.9670
# Feature removed: Visibility
# RMSE: 0.9392, R^2: 0.9685
# Feature removed: VisibilityMax
# RMSE: 0.9336, R^2: 0.9688
# Feature removed: VisibilityMin
# RMSE: 0.9502, R^2: 0.9677
# Feature removed: WindDirection
# RMSE: 0.9225, R^2: 0.9696
# Feature removed: WindSpeed
# RMSE: 0.9617, R^2: 0.9669
# Feature removed: WindSpeedMax
# RMSE: 0.9229, R^2: 0.9696
# Feature removed: WindSpeedMin
# RMSE: 0.9485, R^2: 0.9678

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def final_random_forest_model(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Target is either 'RFL_Att' or 'FSO_Att'

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

    # Train a Random Forest model using all features
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X_train, y_train)

    # Predictions on test data
    y_pred = model.predict(X_test)

    # Calculate RMSE and R^2 for test data
    rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_test = r2_score(y_test, y_pred)

    # Calculate OOB RMSE and R^2 (training data) for comparison
    rmse_oob = np.sqrt(mean_squared_error(y_train, model.oob_prediction_))
    r2_oob = r2_score(y_train, model.oob_prediction_)

    # Print and return results
    print(f"Final Random Forest Model for {target_column}")
    print(f"Test RMSE: {rmse_test:.4f}, Test R^2: {r2_test:.4f}")
    print(f"OOB RMSE (Training): {rmse_oob:.4f}, OOB R^2 (Training): {r2_oob:.4f}")

    return {
        'Test RMSE': rmse_test,
        'Test R^2': r2_test,
        'OOB RMSE (Training)': rmse_oob,
        'OOB R^2 (Training)': r2_oob
    }

# Run final Random Forest model on Snow RFL data
print("Evaluating final model for Snow Weather - RFL subset")
snow_rfl_final_results = final_random_forest_model(snow_rfl_data, target_column='RFL_Att')

# Run final Random Forest model on Snow FSO data
print("\nEvaluating final model for Snow Weather - FSO subset")
snow_fso_final_results = final_random_forest_model(snow_fso_data, target_column='FSO_Att')
# Out:
# Evaluating final model for Snow Weather - RFL subset
# Final Random Forest Model for RFL_Att
# Test RMSE: 0.2910, Test R^2: 0.9547
# OOB RMSE (Training): 0.3715, OOB R^2 (Training): 0.9453
#
# Evaluating final model for Snow Weather - FSO subset
# Final Random Forest Model for FSO_Att
# Test RMSE: 0.9415, Test R^2: 0.9683
# OOB RMSE (Training): 1.3088, OOB R^2 (Training): 0.9384

# %%
import pandas as pd

def calculate_feature_importance_differences(results_df, full_model_results):
    # Calculate the absolute differences in RMSE and R^2 between training (OOB) and test datasets
    results_df['RMSE Difference'] = abs(full_model_results['OOB RMSE (Training)'] - results_df['RMSE'])
    results_df['R^2 Difference'] = abs(full_model_results['OOB R^2 (Training)'] - results_df['R^2'])
    
    # Rank features by importance based on the sum of RMSE and R^2 differences
    results_df['Importance Score'] = results_df['RMSE Difference'] + results_df['R^2 Difference']
    
    # Sort by importance score in descending order
    results_df = results_df.sort_values(by='Importance Score', ascending=False).reset_index(drop=True)
    
    return results_df[['Removed Feature', 'RMSE Difference', 'R^2 Difference', 'Importance Score']]

# Example usage:
print("Calculating feature importance for Snow Weather - RFL subset")
snow_rfl_importance = calculate_feature_importance_differences(snow_rfl_results, snow_rfl_final_results)
print(snow_rfl_importance)

print("\nCalculating feature importance for Snow Weather - FSO subset")
snow_fso_importance = calculate_feature_importance_differences(snow_fso_results, snow_fso_final_results)
print(snow_fso_importance)
# Out:
# Calculating feature importance for Snow Weather - RFL subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0   TemperatureDifference         0.089017        0.012008          0.101025
# 1        AbsoluteHumidity         0.085803        0.011032          0.096834
# 2             Particulate         0.081687        0.009766          0.091453
# 3          ParticulateMin         0.080539        0.009409          0.089948
# 4          ParticulateMax         0.080285        0.009330          0.089615
# 5                Distance         0.078126        0.008656          0.086782
# 6           WindDirection         0.077029        0.008311          0.085340
# 7     AbsoluteHumidityMax         0.076687        0.008203          0.084891
# 8        RelativeHumidity         0.075471        0.007819          0.083291
# 9     AbsoluteHumidityMin         0.075236        0.007745          0.082981
# 10            Temperature         0.075160        0.007721          0.082880
# 11           WindSpeedMin         0.074608        0.007546          0.082154
# 12              WindSpeed         0.073906        0.007323          0.081229
# 13          RainIntensity         0.071850        0.006666          0.078517
# 14          VisibilityMin         0.070847        0.006345          0.077192
# 15       RainIntensityMin         0.070784        0.006324          0.077108
# 16             Visibility         0.070744        0.006311          0.077055
# 17         TemperatureMax         0.070622        0.006272          0.076894
# 18          VisibilityMax         0.070064        0.006093          0.076157
# 19         TemperatureMin         0.068280        0.005516          0.073796
# 20           WindSpeedMax         0.067273        0.005189          0.072462
# 21       RainIntensityMax         0.065143        0.004494          0.069636
# 22                   Time         0.061315        0.003232          0.064547
# 23              Frequency         0.030692        0.007423          0.038115
#
# Calculating feature importance for Snow Weather - FSO subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0           WindDirection         0.386306        0.031202          0.417509
# 1            WindSpeedMax         0.385943        0.031179          0.417122
# 2          ParticulateMax         0.377984        0.030651          0.408635
# 3     AbsoluteHumidityMin         0.377412        0.030613          0.408025
# 4     AbsoluteHumidityMax         0.375685        0.030498          0.406183
# 5          ParticulateMin         0.375297        0.030472          0.405769
# 6           VisibilityMax         0.375282        0.030471          0.405753
# 7              Visibility         0.369612        0.030091          0.399704
# 8        RainIntensityMax         0.367576        0.029955          0.397530
# 9               Frequency         0.365613        0.029822          0.395435
# 10               Distance         0.364357        0.029738          0.394095
# 11       RainIntensityMin         0.364252        0.029731          0.393982
# 12          RainIntensity         0.360823        0.029499          0.390321
# 13           WindSpeedMin         0.360324        0.029465          0.389789
# 14          VisibilityMin         0.358627        0.029350          0.387977
# 15       AbsoluteHumidity         0.358490        0.029340          0.387830
# 16            Particulate         0.357303        0.029260          0.386562
# 17         TemperatureMax         0.355771        0.029155          0.384926
# 18            Temperature         0.352643        0.028942          0.381584
# 19         TemperatureMin         0.348486        0.028657          0.377143
# 20                   Time         0.347398        0.028582          0.375980
# 21              WindSpeed         0.347193        0.028568          0.375761
# 22       RelativeHumidity         0.327896        0.027228          0.355124
# 23  TemperatureDifference         0.235276        0.020426          0.255702

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

def iterative_feature_removal(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]
    
    # Prepare a DataFrame to store the results
    results = pd.DataFrame(columns=['Remaining Features', 'OOB RMSE', 'OOB R^2'])

    # Initialize the list of features to be removed iteratively
    remaining_features = list(predictors.columns)

    while remaining_features:
        # Train the Random Forest model with current set of features
        model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
        model.fit(predictors[remaining_features], target)

        # Calculate OOB RMSE and R^2
        oob_predictions = model.oob_prediction_
        oob_rmse = np.sqrt(mean_squared_error(target, oob_predictions))
        oob_r2 = r2_score(target, oob_predictions)

        # Record the current state
        result_row = pd.DataFrame({
            'Remaining Features': [remaining_features.copy()],
            'OOB RMSE': [oob_rmse],
            'OOB R^2': [oob_r2]
        })
        results = pd.concat([results, result_row], ignore_index=True)

        # Rank features by importance and remove the least important feature
        importances = model.feature_importances_
        least_important_feature = remaining_features[np.argmin(importances)]
        remaining_features.remove(least_important_feature)
        
        # Print the step results
        print(f"Features: {remaining_features}")
        print(f"OOB RMSE: {oob_rmse:.4f}, OOB R^2: {oob_r2:.4f}")
        print(f"Removed Feature: {least_important_feature}\n")
    
    return results

# Run iterative feature removal on Snow RFL subset
print("Iterative feature removal for Snow Weather - RFL subset")
snow_rfl_removal_results = iterative_feature_removal(snow_rfl_data, target_column='RFL_Att')

# Run iterative feature removal on Snow FSO subset
print("\nIterative feature removal for Snow Weather - FSO subset")
snow_fso_removal_results = iterative_feature_removal(snow_fso_data, target_column='FSO_Att')
# Out:
# Iterative feature removal for Snow Weather - RFL subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4816\1220918523.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.3132, OOB R^2: 0.9583
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.3139, OOB R^2: 0.9581
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.3081, OOB R^2: 0.9596
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 0.3106, OOB R^2: 0.9589
# Removed Feature: TemperatureMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3065, OOB R^2: 0.9600
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3057, OOB R^2: 0.9602
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3064, OOB R^2: 0.9601
# Removed Feature: TemperatureMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'Particulate', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3068, OOB R^2: 0.9599
# Removed Feature: VisibilityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.2975, OOB R^2: 0.9623
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'Visibility', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.2975, OOB R^2: 0.9623
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3008, OOB R^2: 0.9615
# Removed Feature: Visibility
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.2973, OOB R^2: 0.9624
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3354, OOB R^2: 0.9521
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'Time', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3327, OOB R^2: 0.9529
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureDifference', 'Time', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 0.3313, OOB R^2: 0.9533
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidity', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'TemperatureDifference', 'Time', 'WindSpeedMax']
# OOB RMSE: 0.3292, OOB R^2: 0.9539
# Removed Feature: VisibilityMin
#
# Features: ['AbsoluteHumidity', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'TemperatureDifference', 'Time', 'WindSpeedMax']
# OOB RMSE: 0.3250, OOB R^2: 0.9551
# Removed Feature: RelativeHumidity
#
# Features: ['RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'TemperatureDifference', 'Time', 'WindSpeedMax']
# OOB RMSE: 0.3330, OOB R^2: 0.9528
# Removed Feature: AbsoluteHumidity
#
# Features: ['RainIntensity', 'RainIntensityMin', 'TemperatureDifference', 'Time', 'WindSpeedMax']
# OOB RMSE: 0.3939, OOB R^2: 0.9340
# Removed Feature: RainIntensityMax
#
# Features: ['RainIntensity', 'TemperatureDifference', 'Time', 'WindSpeedMax']
# OOB RMSE: 0.3953, OOB R^2: 0.9335
# Removed Feature: RainIntensityMin
#
# Features: ['RainIntensity', 'TemperatureDifference', 'WindSpeedMax']
# OOB RMSE: 0.3966, OOB R^2: 0.9331
# Removed Feature: Time
#
# Features: ['RainIntensity', 'TemperatureDifference']
# OOB RMSE: 0.4352, OOB R^2: 0.9194
# Removed Feature: WindSpeedMax
#
# Features: ['TemperatureDifference']
# OOB RMSE: 0.5121, OOB R^2: 0.8884
# Removed Feature: RainIntensity
#
# Features: []
# OOB RMSE: 0.8035, OOB R^2: 0.7253
# Removed Feature: TemperatureDifference
#
#
# Iterative feature removal for Snow Weather - FSO subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_4816\1220918523.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1713, OOB R^2: 0.9510
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1678, OOB R^2: 0.9513
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1666, OOB R^2: 0.9514
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1627, OOB R^2: 0.9517
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'Distance', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1674, OOB R^2: 0.9513
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMin', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1607, OOB R^2: 0.9519
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidityMin', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1518, OOB R^2: 0.9526
# Removed Feature: AbsoluteHumidity
#
# Features: ['AbsoluteHumidityMin', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1454, OOB R^2: 0.9531
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidityMin', 'Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1443, OOB R^2: 0.9532
# Removed Feature: RainIntensity
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1073, OOB R^2: 0.9562
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.1219, OOB R^2: 0.9550
# Removed Feature: VisibilityMin
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'WindSpeedMax']
# OOB RMSE: 1.1220, OOB R^2: 0.9550
# Removed Feature: WindSpeedMin
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 1.0728, OOB R^2: 0.9589
# Removed Feature: VisibilityMax
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 1.0647, OOB R^2: 0.9595
# Removed Feature: Time
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'Visibility', 'WindSpeedMax']
# OOB RMSE: 1.1073, OOB R^2: 0.9562
# Removed Feature: TemperatureMin
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'WindSpeedMax']
# OOB RMSE: 1.1061, OOB R^2: 0.9563
# Removed Feature: Visibility
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'WindSpeedMax']
# OOB RMSE: 1.2391, OOB R^2: 0.9451
# Removed Feature: TemperatureMax
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference']
# OOB RMSE: 1.2362, OOB R^2: 0.9454
# Removed Feature: WindSpeedMax
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'Temperature', 'TemperatureDifference']
# OOB RMSE: 1.3581, OOB R^2: 0.9341
# Removed Feature: RelativeHumidity
#
# Features: ['Particulate', 'ParticulateMax', 'ParticulateMin', 'TemperatureDifference']
# OOB RMSE: 1.2766, OOB R^2: 0.9418
# Removed Feature: Temperature
#
# Features: ['Particulate', 'ParticulateMax', 'TemperatureDifference']
# OOB RMSE: 1.7674, OOB R^2: 0.8884
# Removed Feature: ParticulateMin
#
# Features: ['Particulate', 'ParticulateMax']
# OOB RMSE: 1.6839, OOB R^2: 0.8987
# Removed Feature: TemperatureDifference
#
# Features: ['Particulate']
# OOB RMSE: 2.8560, OOB R^2: 0.7086
# Removed Feature: ParticulateMax
#
# Features: []
# OOB RMSE: 3.0406, OOB R^2: 0.6697
# Removed Feature: Particulate

# %%
print(snow_rfl_removal_results.columns)
# Out:
# Index(['Remaining Features', 'OOB RMSE', 'OOB R^2'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def add_removed_feature_column(results_df):
    # Extract all features in the initial (first row) 'Remaining Features' column
    all_features = set(results_df['Remaining Features'].iloc[0])
    
    # Initialize a list to store removed features
    removed_features = []
    
    # Set to track already removed features
    remaining_features = all_features.copy()

    # Compute removed features at each step
    for i in range(len(results_df)):
        current_features = set(results_df['Remaining Features'].iloc[i])
        removed = list(remaining_features - current_features)
        
        # Add the removed feature to the list, and remove it from the remaining features set
        if removed:
            removed_feature = removed[0]
            removed_features.append(removed_feature)
            remaining_features.remove(removed_feature)
        else:
            removed_features.append(None)  # No feature removed (last step)

    # Add the new column to the DataFrame
    results_df['Removed Feature'] = removed_features
    return results_df

# Update results DataFrames to include 'Removed Feature'
snow_rfl_removal_results = add_removed_feature_column(snow_rfl_removal_results)
snow_fso_removal_results = add_removed_feature_column(snow_fso_removal_results)

def plot_rmse_r2(results_df, title):
    # Verify columns exist
    expected_columns = ['OOB RMSE', 'OOB R^2', 'Removed Feature']
    for col in expected_columns:
        if col not in results_df.columns:
            raise KeyError(f"Expected column '{col}' not found in DataFrame.")

    # Extract RMSE, R^2 values, and removed features
    rmse_values = results_df['OOB RMSE']
    r2_values = results_df['OOB R^2']
    features_removed = range(len(results_df))
    removed_feature_names = results_df['Removed Feature']

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    ax1.plot(features_removed, rmse_values, color="blue", marker="o", label="RMSE")
    ax1.set_xlabel("Features Removed")
    ax1.set_ylabel("RMSE (dB)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(features_removed, r2_values, color="orange", marker="o", label="R^2")
    ax2.set_ylabel("R^2", color="orange")
    ax2.tick_params(axis="y", labelcolor="orange")

    # Place the removed feature names horizontally under the x-axis
    ax1.set_xticks(features_removed)
    ax1.set_xticklabels(removed_feature_names, rotation=90, ha='center', fontsize=8, color="black")

    separation_point = len(results_df) - 10
    ax1.axvline(x=separation_point, color="green", linestyle="--", label="Important Feature Separation")

    plt.title(title)
    fig.tight_layout()
    fig.legend(loc="upper right")
    plt.show()

# Plot updated DataFrames with removed feature names under the x-axis in order of removal
plot_rmse_r2(snow_rfl_removal_results, "Snow Weather - RFL")
plot_rmse_r2(snow_fso_removal_results, "Snow Weather - FSO")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Identify features to the right of the green line
def get_important_features(results_df, separation_point):
    # Get the features from the green line to the end of the list
    important_features = results_df['Removed Feature'][separation_point:].dropna().tolist()
    return important_features

# Train Random Forest on selected features
def train_random_forest_on_important_features(data, target_column, important_features):
    # Subset the data to include only the important features
    X = data[important_features]
    y = data[target_column]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X, y)

    # Calculate RMSE and R^2 on OOB (Out-of-Bag) predictions
    oob_predictions = model.oob_prediction_
    rmse = np.sqrt(mean_squared_error(y, oob_predictions))
    r2 = r2_score(y, oob_predictions)
    
    return rmse, r2, model

# Define the separation point (assuming last 10 features are considered important)
separation_point = len(snow_rfl_removal_results) - 10

# Get important features based on the green line separation for both RFL and FSO
important_features_rfl = get_important_features(snow_rfl_removal_results, separation_point)
important_features_fso = get_important_features(snow_fso_removal_results, separation_point)

# Assume 'data' is your main dataset containing the predictor variables and the target column 'RFL_Att' for RFL subset and 'FSO_Att' for FSO subset.
# Replace 'data' with the appropriate variable name if it's different.

# Train and evaluate the model for RFL
rmse_rfl, r2_rfl, model_rfl = train_random_forest_on_important_features(data, 'RFL_Att', important_features_rfl)
print(f"RFL Model - RMSE: {rmse_rfl:.4f}, R^2: {r2_rfl:.4f}")

# Train and evaluate the model for FSO
rmse_fso, r2_fso, model_fso = train_random_forest_on_important_features(data, 'FSO_Att', important_features_fso)
print(f"FSO Model - RMSE: {rmse_fso:.4f}, R^2: {r2_fso:.4f}")
# Out:
# RFL Model - RMSE: 0.9002, R^2: 0.9315
# FSO Model - RMSE: 1.0593, R^2: 0.9264
