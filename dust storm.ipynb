# %%
import pandas as pd

# Load the dataset 
file_path = r"C:\Users\punee\Downloads\Aditi coding\RFLFSODataFull.csv"
data = pd.read_csv(file_path)

# Creating separate data subsets for each weather condition
clear_data = data[data['SYNOPCode'] == 0]      
dust_storm_data = data[data['SYNOPCode'] == 3] 
fog_data = data[data['SYNOPCode'] == 4]         
drizzle_data = data[data['SYNOPCode'] == 5]    
rain_data = data[data['SYNOPCode'] == 6]        
snow_data = data[data['SYNOPCode'] == 7]        
showers_data = data[data['SYNOPCode'] == 8]    

# Step 3: Verify the size of each subset 
print("Number of entries in each subset:")
print("Clear:", len(clear_data))
print("Dust Storm:", len(dust_storm_data))
print("Fog:", len(fog_data))
print("Drizzle:", len(drizzle_data))
print("Rain:", len(rain_data))
print("Snow:", len(snow_data))
print("Showers:", len(showers_data))
# Out:
# Number of entries in each subset:
# Clear: 56964
# Dust Storm: 191
# Fog: 466
# Drizzle: 6605
# Rain: 25018
# Snow: 419
# Showers: 1716

# %%
# Filter the data to get only the "Dust storm" weather condition 
dust_storm_data = data[data['SYNOPCode'] == 3]

# Separate the "Dust storm" data further based on "RFL" and "FSO" attributes

# Filter rows with RFL data (where 'RFL_Att' has values)
dust_storm_rfl_data = dust_storm_data.dropna(subset=['RFL_Att'])

# Filter rows with FSO data (where 'FSO_Att' has values)
dust_storm_fso_data = dust_storm_data.dropna(subset=['FSO_Att'])

# Verify the sizes of each subset
print("Number of entries in Dust storm (RFL):", len(dust_storm_rfl_data))
print("Number of entries in Dust storm (FSO):", len(dust_storm_fso_data))
# Out:
# Number of entries in Dust storm (RFL): 191
# Number of entries in Dust storm (FSO): 191

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Assuming you have already run Step 1 and created dust_storm_rfl_data and dust_storm_fso_data

def evaluate_models(data, target_column):
    # Drop columns that are not predictors (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Set the target column, either 'RFL_Att' or 'FSO_Att'
    
    # Prepare to store RMSE and R^2 scores for each feature removed
    rmse_scores = []
    r2_scores = []
    removed_features = []

    # Loop through each column, removing it and training a model
    for feature in predictors.columns:
        # Drop the feature from the predictors
        predictors_subset = predictors.drop(columns=[feature])
        
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(predictors_subset, target, test_size=0.3, random_state=42)
        
        # Train a Random Forest model
        model = RandomForestRegressor(n_estimators=100, random_state=42)
        model.fit(X_train, y_train)
        
        # Predictions on test data
        y_pred = model.predict(X_test)
        
        # Calculate RMSE and R^2
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        
        # Store the results
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        removed_features.append(feature)
        
        # Print results for each model
        print(f"Feature removed: {feature}")
        print(f"RMSE: {rmse:.4f}, R^2: {r2:.4f}")
    
    # Store the results in a DataFrame for easier handling
    results_df = pd.DataFrame({
        'Removed Feature': removed_features,
        'RMSE': rmse_scores,
        'R^2': r2_scores
    })
    
    return results_df

# Run evaluation on Dust storm RFL data
print("Evaluating models for Dust storm Weather - RFL subset")
dust_storm_rfl_results = evaluate_models(dust_storm_rfl_data, target_column='RFL_Att')

# Run evaluation on Dust storm FSO data
print("\nEvaluating models for Dust storm Weather - FSO subset")
dust_storm_fso_results = evaluate_models(dust_storm_fso_data, target_column='FSO_Att')
# Out:
# Evaluating models for Dust storm Weather - RFL subset
# Feature removed: AbsoluteHumidity
# RMSE: 0.4107, R^2: 0.9824
# Feature removed: AbsoluteHumidityMax
# RMSE: 0.3892, R^2: 0.9842
# Feature removed: AbsoluteHumidityMin
# RMSE: 0.3884, R^2: 0.9843
# Feature removed: Distance
# RMSE: 0.3844, R^2: 0.9846
# Feature removed: Frequency
# RMSE: 0.4464, R^2: 0.9792
# Feature removed: Particulate
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: ParticulateMax
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: ParticulateMin
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: RainIntensity
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: RainIntensityMax
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: RainIntensityMin
# RMSE: 0.3961, R^2: 0.9837
# Feature removed: RelativeHumidity
# RMSE: 0.3983, R^2: 0.9835
# Feature removed: Temperature
# RMSE: 0.3849, R^2: 0.9846
# Feature removed: TemperatureDifference
# RMSE: 0.4166, R^2: 0.9819
# Feature removed: TemperatureMax
# RMSE: 0.3833, R^2: 0.9847
# Feature removed: TemperatureMin
# RMSE: 0.3871, R^2: 0.9844
# Feature removed: Time
# RMSE: 0.4196, R^2: 0.9817
# Feature removed: Visibility
# RMSE: 0.3852, R^2: 0.9845
# Feature removed: VisibilityMax
# RMSE: 0.3946, R^2: 0.9838
# Feature removed: VisibilityMin
# RMSE: 0.3883, R^2: 0.9843
# Feature removed: WindDirection
# RMSE: 0.3824, R^2: 0.9848
# Feature removed: WindSpeed
# RMSE: 0.3880, R^2: 0.9843
# Feature removed: WindSpeedMax
# RMSE: 0.3869, R^2: 0.9844
# Feature removed: WindSpeedMin
# RMSE: 0.3934, R^2: 0.9839
#
# Evaluating models for Dust storm Weather - FSO subset
# Feature removed: AbsoluteHumidity
# RMSE: 2.0283, R^2: 0.9493
# Feature removed: AbsoluteHumidityMax
# RMSE: 1.9829, R^2: 0.9516
# Feature removed: AbsoluteHumidityMin
# RMSE: 1.9972, R^2: 0.9509
# Feature removed: Distance
# RMSE: 1.7333, R^2: 0.9630
# Feature removed: Frequency
# RMSE: 1.9511, R^2: 0.9531
# Feature removed: Particulate
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: ParticulateMax
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: ParticulateMin
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: RainIntensity
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: RainIntensityMax
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: RainIntensityMin
# RMSE: 2.0042, R^2: 0.9505
# Feature removed: RelativeHumidity
# RMSE: 2.1001, R^2: 0.9457
# Feature removed: Temperature
# RMSE: 2.0181, R^2: 0.9498
# Feature removed: TemperatureDifference
# RMSE: 2.1865, R^2: 0.9411
# Feature removed: TemperatureMax
# RMSE: 1.9915, R^2: 0.9511
# Feature removed: TemperatureMin
# RMSE: 1.9912, R^2: 0.9511
# Feature removed: Time
# RMSE: 2.2823, R^2: 0.9358
# Feature removed: Visibility
# RMSE: 1.9359, R^2: 0.9538
# Feature removed: VisibilityMax
# RMSE: 2.0068, R^2: 0.9504
# Feature removed: VisibilityMin
# RMSE: 1.9681, R^2: 0.9523
# Feature removed: WindDirection
# RMSE: 1.9456, R^2: 0.9534
# Feature removed: WindSpeed
# RMSE: 1.9818, R^2: 0.9516
# Feature removed: WindSpeedMax
# RMSE: 2.0027, R^2: 0.9506
# Feature removed: WindSpeedMin
# RMSE: 1.9748, R^2: 0.9519

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def final_random_forest_model(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]  # Target is either 'RFL_Att' or 'FSO_Att'

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

    # Train a Random Forest model using all features
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X_train, y_train)

    # Predictions on test data
    y_pred = model.predict(X_test)

    # Calculate RMSE and R^2 for test data
    rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
    r2_test = r2_score(y_test, y_pred)

    # Calculate OOB RMSE and R^2 (training data) for comparison
    rmse_oob = np.sqrt(mean_squared_error(y_train, model.oob_prediction_))
    r2_oob = r2_score(y_train, model.oob_prediction_)

    # Print and return results
    
    print(f"Final Random Forest Model for {target_column}")
    print(f"Test RMSE: {rmse_test:.4f}, Test R^2: {r2_test:.4f}")
    print(f"OOB RMSE (Training): {rmse_oob:.4f}, OOB R^2 (Training): {r2_oob:.4f}")

    return {
        'Test RMSE': rmse_test,
        'Test R^2': r2_test,
        'OOB RMSE (Training)': rmse_oob,
        'OOB R^2 (Training)': r2_oob
    }

# Run final Random Forest model on Dust storm RFL data
print("Evaluating final model for Dust storm Weather - RFL subset")
dust_storm_rfl_final_results = final_random_forest_model(dust_storm_rfl_data, target_column='RFL_Att')

# Run final Random Forest model on Dust storm FSO data
print("\nEvaluating final model for Dust storm Weather - FSO subset")
dust_storm_fso_final_results = final_random_forest_model(dust_storm_fso_data, target_column='FSO_Att')
# Out:
# Evaluating final model for Dust storm Weather - RFL subset
# Final Random Forest Model for RFL_Att
# Test RMSE: 0.3970, Test R^2: 0.9836
# OOB RMSE (Training): 0.6325, OOB R^2 (Training): 0.9539
#
# Evaluating final model for Dust storm Weather - FSO subset
# Final Random Forest Model for FSO_Att
# Test RMSE: 1.9846, Test R^2: 0.9515
# OOB RMSE (Training): 2.7312, OOB R^2 (Training): 0.8760

# %%
import pandas as pd

def calculate_feature_importance_differences(results_df, full_model_results):
    # Calculate the absolute differences in RMSE and R^2 between training (OOB) and test datasets
    results_df['RMSE Difference'] = abs(full_model_results['OOB RMSE (Training)'] - results_df['RMSE'])
    results_df['R^2 Difference'] = abs(full_model_results['OOB R^2 (Training)'] - results_df['R^2'])
    
    # Rank features by importance based on the sum of RMSE and R^2 differences
    results_df['Importance Score'] = results_df['RMSE Difference'] + results_df['R^2 Difference']
    
    # Sort by importance score in descending order
    results_df = results_df.sort_values(by='Importance Score', ascending=False).reset_index(drop=True)
    
    return results_df[['Removed Feature', 'RMSE Difference', 'R^2 Difference', 'Importance Score']]

# Example usage:
print("Calculating feature importance for Dust storm Weather - RFL subset")
dust_storm_rfl_importance = calculate_feature_importance_differences(dust_storm_rfl_results, dust_storm_rfl_final_results)
print(dust_storm_rfl_importance)

print("\nCalculating feature importance for Dust storm Weather - FSO subset")
dust_storm_fso_importance = calculate_feature_importance_differences(dust_storm_fso_results, dust_storm_fso_final_results)
print(dust_storm_fso_importance)
# Out:
# Calculating feature importance for Dust storm Weather - RFL subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0           WindDirection         0.250063        0.030819          0.280881
# 1          TemperatureMax         0.249221        0.030751          0.279972
# 2                Distance         0.248132        0.030664          0.278797
# 3             Temperature         0.247577        0.030620          0.278197
# 4              Visibility         0.247325        0.030600          0.277924
# 5            WindSpeedMax         0.245642        0.030464          0.276106
# 6          TemperatureMin         0.245421        0.030447          0.275868
# 7               WindSpeed         0.244493        0.030372          0.274864
# 8           VisibilityMin         0.244214        0.030349          0.274563
# 9     AbsoluteHumidityMin         0.244093        0.030339          0.274432
# 10    AbsoluteHumidityMax         0.243331        0.030278          0.273609
# 11           WindSpeedMin         0.239128        0.029935          0.269063
# 12          VisibilityMax         0.237896        0.029834          0.267730
# 13       RainIntensityMin         0.236410        0.029712          0.266122
# 14       RainIntensityMax         0.236410        0.029712          0.266122
# 15          RainIntensity         0.236410        0.029712          0.266122
# 16         ParticulateMin         0.236410        0.029712          0.266122
# 17         ParticulateMax         0.236410        0.029712          0.266122
# 18            Particulate         0.236410        0.029712          0.266122
# 19       RelativeHumidity         0.234233        0.029532          0.263765
# 20       AbsoluteHumidity         0.221746        0.028479          0.250225
# 21  TemperatureDifference         0.215923        0.027978          0.243901
# 22                   Time         0.212915        0.027716          0.240631
# 23              Frequency         0.186069        0.025294          0.211364
#
# Calculating feature importance for Dust storm Weather - FSO subset
#           Removed Feature  RMSE Difference  R^2 Difference  Importance Score
# 0                Distance         0.997912        0.087009          1.084921
# 1              Visibility         0.795312        0.077850          0.873161
# 2           WindDirection         0.785591        0.077385          0.862976
# 3               Frequency         0.780042        0.077118          0.857161
# 4           VisibilityMin         0.763104        0.076300          0.839404
# 5            WindSpeedMin         0.756381        0.075974          0.832355
# 6               WindSpeed         0.749343        0.075631          0.824974
# 7     AbsoluteHumidityMax         0.748304        0.075580          0.823884
# 8          TemperatureMin         0.739920        0.075169          0.815089
# 9          TemperatureMax         0.739662        0.075157          0.814818
# 10    AbsoluteHumidityMin         0.734008        0.074879          0.808887
# 11           WindSpeedMax         0.728481        0.074606          0.803088
# 12       RainIntensityMax         0.726968        0.074532          0.801499
# 13       RainIntensityMin         0.726968        0.074532          0.801499
# 14          RainIntensity         0.726968        0.074532          0.801499
# 15         ParticulateMin         0.726968        0.074532          0.801499
# 16         ParticulateMax         0.726968        0.074532          0.801499
# 17            Particulate         0.726968        0.074532          0.801499
# 18          VisibilityMax         0.724326        0.074401          0.798727
# 19            Temperature         0.713092        0.073844          0.786936
# 20       AbsoluteHumidity         0.702863        0.073334          0.776197
# 21       RelativeHumidity         0.631032        0.069680          0.700712
# 22  TemperatureDifference         0.544694        0.065120          0.609814
# 23                   Time         0.448913        0.059846          0.508759

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

def iterative_feature_removal(data, target_column):
    # Drop non-predictor columns (SYNOPCode, RFL_Att, FSO_Att)
    predictors = data.drop(columns=['SYNOPCode', 'RFL_Att', 'FSO_Att'])
    target = data[target_column]
    
    # Prepare a DataFrame to store the results
    results = pd.DataFrame(columns=['Remaining Features', 'OOB RMSE', 'OOB R^2'])

    # Initialize the list of features to be removed iteratively
    remaining_features = list(predictors.columns)

    while remaining_features:
        # Train the Random Forest model with current set of features
        model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
        model.fit(predictors[remaining_features], target)

        # Calculate OOB RMSE and R^2
        oob_predictions = model.oob_prediction_
        oob_rmse = np.sqrt(mean_squared_error(target, oob_predictions))
        oob_r2 = r2_score(target, oob_predictions)

        # Record the current state
        result_row = pd.DataFrame({
            'Remaining Features': [remaining_features.copy()],
            'OOB RMSE': [oob_rmse],
            'OOB R^2': [oob_r2]
        })
        results = pd.concat([results, result_row], ignore_index=True)

        # Rank features by importance and remove the least important feature
        importances = model.feature_importances_
        least_important_feature = remaining_features[np.argmin(importances)]
        remaining_features.remove(least_important_feature)
        
        # Print the step results
        print(f"Features: {remaining_features}")
        print(f"OOB RMSE: {oob_rmse:.4f}, OOB R^2: {oob_r2:.4f}")
        print(f"Removed Feature: {least_important_feature}\n")
    
    return results

# Run iterative feature removal on Dust storm RFL subset
print("Iterative feature removal for Dust storm Weather - RFL subset")
dust_storm_rfl_removal_results = iterative_feature_removal(dust_storm_rfl_data, target_column='RFL_Att')

# Run iterative feature removal on Dust storm FSO subset
print("\nIterative feature removal for Dust storm Weather - FSO subset")
dust_storm_fso_removal_results = iterative_feature_removal(dust_storm_fso_data, target_column='FSO_Att')
# Out:
# Iterative feature removal for Dust storm Weather - RFL subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_15928\4179913773.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5194, OOB R^2: 0.9700
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.4998, OOB R^2: 0.9723
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5192, OOB R^2: 0.9701
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5040, OOB R^2: 0.9718
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5179, OOB R^2: 0.9702
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5342, OOB R^2: 0.9683
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 0.5002, OOB R^2: 0.9722
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeedMax']
# OOB RMSE: 0.5310, OOB R^2: 0.9687
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection']
# OOB RMSE: 0.5030, OOB R^2: 0.9719
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 0.5086, OOB R^2: 0.9713
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax']
# OOB RMSE: 0.5034, OOB R^2: 0.9719
# Removed Feature: VisibilityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility']
# OOB RMSE: 0.4802, OOB R^2: 0.9744
# Removed Feature: VisibilityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility']
# OOB RMSE: 0.4990, OOB R^2: 0.9724
# Removed Feature: Distance
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility']
# OOB RMSE: 0.4955, OOB R^2: 0.9727
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.5460, OOB R^2: 0.9669
# Removed Feature: Visibility
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.5778, OOB R^2: 0.9629
# Removed Feature: RelativeHumidity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Temperature', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.5804, OOB R^2: 0.9626
# Removed Feature: TemperatureDifference
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.5831, OOB R^2: 0.9623
# Removed Feature: Temperature
#
# Features: ['AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.6147, OOB R^2: 0.9580
# Removed Feature: AbsoluteHumidity
#
# Features: ['AbsoluteHumidityMax', 'TemperatureMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.6359, OOB R^2: 0.9551
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['AbsoluteHumidityMax', 'TemperatureMin', 'Time']
# OOB RMSE: 0.6556, OOB R^2: 0.9523
# Removed Feature: TemperatureMax
#
# Features: ['TemperatureMin', 'Time']
# OOB RMSE: 0.6734, OOB R^2: 0.9497
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['Time']
# OOB RMSE: 0.6598, OOB R^2: 0.9517
# Removed Feature: TemperatureMin
#
# Features: []
# OOB RMSE: 0.9123, OOB R^2: 0.9076
# Removed Feature: Time
#
#
# Iterative feature removal for Dust storm Weather - FSO subset
# C:\Users\punee\AppData\Local\Temp\ipykernel_15928\4179913773.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result_row], ignore_index=True)
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMax', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9918, OOB R^2: 0.9405
# Removed Feature: Particulate
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'ParticulateMin', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9667, OOB R^2: 0.9420
# Removed Feature: ParticulateMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensity', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9334, OOB R^2: 0.9440
# Removed Feature: ParticulateMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensityMax', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 2.0084, OOB R^2: 0.9395
# Removed Feature: RainIntensity
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RainIntensityMin', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9255, OOB R^2: 0.9444
# Removed Feature: RainIntensityMax
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'Frequency', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 2.0608, OOB R^2: 0.9363
# Removed Feature: RainIntensityMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindDirection', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9852, OOB R^2: 0.9409
# Removed Feature: Frequency
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax', 'WindSpeedMin']
# OOB RMSE: 1.9655, OOB R^2: 0.9421
# Removed Feature: WindDirection
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeed', 'WindSpeedMax']
# OOB RMSE: 1.9566, OOB R^2: 0.9426
# Removed Feature: WindSpeedMin
#
# Features: ['AbsoluteHumidity', 'AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 1.9841, OOB R^2: 0.9410
# Removed Feature: WindSpeed
#
# Features: ['AbsoluteHumidityMax', 'AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 1.9218, OOB R^2: 0.9446
# Removed Feature: AbsoluteHumidity
#
# Features: ['AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin', 'WindSpeedMax']
# OOB RMSE: 1.8852, OOB R^2: 0.9467
# Removed Feature: AbsoluteHumidityMax
#
# Features: ['AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMax', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 2.0081, OOB R^2: 0.9396
# Removed Feature: WindSpeedMax
#
# Features: ['AbsoluteHumidityMin', 'Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.9328, OOB R^2: 0.9440
# Removed Feature: TemperatureMax
#
# Features: ['Distance', 'RelativeHumidity', 'Temperature', 'TemperatureDifference', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.8089, OOB R^2: 0.9510
# Removed Feature: AbsoluteHumidityMin
#
# Features: ['Distance', 'RelativeHumidity', 'Temperature', 'TemperatureMin', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.8839, OOB R^2: 0.9468
# Removed Feature: TemperatureDifference
#
# Features: ['Distance', 'RelativeHumidity', 'Temperature', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.6852, OOB R^2: 0.9574
# Removed Feature: TemperatureMin
#
# Features: ['Distance', 'Temperature', 'Time', 'Visibility', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.7906, OOB R^2: 0.9519
# Removed Feature: RelativeHumidity
#
# Features: ['Distance', 'Temperature', 'Time', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.8033, OOB R^2: 0.9513
# Removed Feature: Visibility
#
# Features: ['Distance', 'Temperature', 'VisibilityMax', 'VisibilityMin']
# OOB RMSE: 1.8681, OOB R^2: 0.9477
# Removed Feature: Time
#
# Features: ['Distance', 'Temperature', 'VisibilityMax']
# OOB RMSE: 1.9336, OOB R^2: 0.9440
# Removed Feature: VisibilityMin
#
# Features: ['Distance', 'VisibilityMax']
# OOB RMSE: 1.8961, OOB R^2: 0.9461
# Removed Feature: Temperature
#
# Features: ['VisibilityMax']
# OOB RMSE: 3.3358, OOB R^2: 0.8332
# Removed Feature: Distance
#
# Features: []
# OOB RMSE: 5.5486, OOB R^2: 0.5386
# Removed Feature: VisibilityMax

# %%
print(dust_storm_rfl_removal_results.columns)
# Out:
# Index(['Remaining Features', 'OOB RMSE', 'OOB R^2'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

def add_removed_feature_column(results_df):
    # Extract all features in the initial (first row) 'Remaining Features' column
    all_features = set(results_df['Remaining Features'].iloc[0])
    
    # Initialize a list to store removed features
    removed_features = []
    
    # Set to track already removed features
    remaining_features = all_features.copy()

    # Compute removed features at each step
    for i in range(len(results_df)):
        current_features = set(results_df['Remaining Features'].iloc[i])
        removed = list(remaining_features - current_features)
        
        # Add the removed feature to the list, and remove it from the remaining features set
        if removed:
            removed_feature = removed[0]
            removed_features.append(removed_feature)
            remaining_features.remove(removed_feature)
        else:
            removed_features.append(None)  # No feature removed (last step)

    # Add the new column to the DataFrame
    results_df['Removed Feature'] = removed_features
    return results_df

# Update results DataFrames to include 'Removed Feature'
dust_storm_rfl_removal_results = add_removed_feature_column(dust_storm_rfl_removal_results)
dust_storm_fso_removal_results = add_removed_feature_column(dust_storm_fso_removal_results)

def plot_rmse_r2(results_df, title, window_size=3):
    # Verify columns exist
    expected_columns = ['OOB RMSE', 'OOB R^2', 'Removed Feature']
    for col in expected_columns:
        if col not in results_df.columns:
            raise KeyError(f"Expected column '{col}' not found in DataFrame.")

    # Extract RMSE, R^2 values, and removed features
    rmse_values = results_df['OOB RMSE']
    r2_values = results_df['OOB R^2']
    features_removed = range(len(results_df))
    removed_feature_names = results_df['Removed Feature']

    # Apply smoothing using a rolling window for both RMSE and R^2
    rmse_smoothed = rmse_values.rolling(window=window_size, min_periods=1).mean()
    r2_smoothed = r2_values.rolling(window=window_size, min_periods=1).mean()

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    ax1.plot(features_removed, rmse_smoothed, color="blue", marker="o", label="RMSE (Smoothed)")
    ax1.set_xlabel("Features Removed")
    ax1.set_ylabel("RMSE (dB)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(features_removed, r2_smoothed, color="orange", marker="o", label="R^2 (Smoothed)")
    ax2.set_ylabel("R^2", color="orange")
    ax2.tick_params(axis="y", labelcolor="orange")

    # Place the removed feature names horizontally under the x-axis
    ax1.set_xticks(features_removed)
    ax1.set_xticklabels(removed_feature_names, rotation=90, ha='center', fontsize=8, color="black")

    separation_point = len(results_df) - 10
    ax1.axvline(x=separation_point, color="green", linestyle="--", label="Important Feature Separation")

    plt.title(title)
    fig.tight_layout()
    fig.legend(loc="upper right")
    plt.show()

# Plot updated DataFrames with removed feature names under the x-axis in order of removal
plot_rmse_r2(dust_storm_rfl_removal_results, "Dust_storm Weather - RFL (Smoothed)")
plot_rmse_r2(dust_storm_fso_removal_results, "Dust_storm Weather - FSO")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Identify features to the right of the green line
def get_important_features(results_df, separation_point):
    # Get the features from the green line to the end of the list
    important_features = results_df['Removed Feature'][separation_point:].dropna().tolist()
    return important_features

# Train Random Forest on selected features
def train_random_forest_on_important_features(data, target_column, important_features):
    # Subset the data to include only the important features
    X = data[important_features]
    y = data[target_column]

    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42, oob_score=True)
    model.fit(X, y)

    # Calculate RMSE and R^2 on OOB (Out-of-Bag) predictions
    oob_predictions = model.oob_prediction_
    rmse = np.sqrt(mean_squared_error(y, oob_predictions))
    r2 = r2_score(y, oob_predictions)
    
    return rmse, r2, model

# Define the separation point (assuming last 10 features are considered important)
separation_point = len(dust_storm_rfl_removal_results) - 10

# Get important features based on the green line separation for both RFL and FSO
important_features_rfl = get_important_features(dust_storm_rfl_removal_results, separation_point)
important_features_fso = get_important_features(dust_storm_fso_removal_results, separation_point)



# Train and evaluate the model for RFL
rmse_rfl, r2_rfl, model_rfl = train_random_forest_on_important_features(data, 'RFL_Att', important_features_rfl)
print(f"RFL Model - RMSE: {rmse_rfl:.4f}, R^2: {r2_rfl:.4f}")

# Train and evaluate the model for FSO
rmse_fso, r2_fso, model_fso = train_random_forest_on_important_features(data, 'FSO_Att', important_features_fso)
print(f"FSO Model - RMSE: {rmse_fso:.4f}, R^2: {r2_fso:.4f}")
# Out:
# RFL Model - RMSE: 1.6112, R^2: 0.7805
# FSO Model - RMSE: 0.9471, R^2: 0.9411
